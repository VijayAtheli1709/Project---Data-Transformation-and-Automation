# %% [markdown]
# # Instructions
#
# For Part A, you need to scrape IMDB web page to find out top movies sorted by user votes. For each movie, you need to pull :
# - movie_id
# - rank
# - title
# - runtime
# - year
# - rating
# - votes
#
# The URL of an page that include movies released between 2018 and 2020 sorted by number of votes is:
#
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
#
# Please click the URL and investigate how you can pull movie_id, rank, title,... from the webpage.
#
#
# **You need to write code after where I have <span style="color:red">'''  Your code here ...    '''.</span>**
#
# ***
# Now let’s look at the read_m_from_html_string(url, num_of_m=50) function in detail. The parameter “num_of_m” in the function def read_m_from_html_string(url, num_of_m=50)
#   represents the top number of movies you want to retrieve. For example, read_m_from_html_string(url,500) means that we want to extract top 500 movies released between, sorted by users' votes.
#
# This function returns a list of dictionaries. Each dictionary represents one of the top movies, which could look like the following:
#
# {
#
#     'movie_id': 'tt7286456',
#     'rank': '1.',
#     'title': 'Joker',
#     'runtime': 2h 2m,
#     'year': '2019',
#     'rating': '8.4',
#     'votes': '1,421,777',
# }
#
#
# After you implement “read_m_from_html_string”, which will return a list of top movies, you need to export the movies list to a csv file.
#
#
# ***
#
# After you done with scraping the needed data, you should clean and transform it as needed to make it ready for enriching the given "Movies.csv" dataset.
# ***
#
# Finaly, export the enriched dataset to a CSV file:
# Use the following naming convention: Project_3_PartA_Lastname.csv

# %%
import warnings
warnings.filterwarnings('ignore')
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ***
#
# ## read_m_from_html_string
#
# Inside this function, you need to write your code to pull the movies information from the provided Movies 500 HTML String text file.
#
# For each movie, you need to pull :
# - movie_id
# - rank
# - title
# - runtime
# - year
# - rating
# - votes
#
# To give examples on how to pull data from the web bage html string, I have included the code to pull the movie_id.
# You need to inculde your code to pull the other needed movie information (title, rank, year, ......). You should have no missing values for each of the collected data.
#
# The URL of an page that include movies released between 2018 and 2020 sorted by number of votes is:
#
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
#
# Please click the URL and investigate how you can pull movie_id, rank, title,... from the webpage using the Inspect option.

# %%
# This function, read a number of movies from a url html string. The default value is 50
def read_m_from_html_string(url, num_of_m=50):
    
    print(url)
    
    with open('TopVoted_500_Movies_HTML.txt', 'r', encoding="utf8") as file:
        html_string = file.read()   # to read the hmtl file as a string
        # I have included the Movies 500 HTML String.txt file in the project folder. Please take a look.
    
    # create a soup object
    soup = BeautifulSoup(html_string, "html.parser")
    
    '''
    Click the URL and investigate how you can pull movie_id, rank, title,... from the webpage.
    To investigate the html of a web page , For example:
    URL: https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
    Right-click anywhere on the webpage, and at the very bottom of the menu that pops up, 
    you will see "Inspect", Click on it.
    '''
    '''
    Fetching a div that includes all the movies. This can be done by using find and find_all functions.
    for example, find_all('div') will give you all divs on the page. Actually, 
    this find or find_all function can have two parameters,
    in the code below 'div' is the tag name and 'ipc-page-grid__item ipc-page-grid__item--span-2' is an attribute 
    value of the tag. You can also do movie_list = soup.find('div', 'ipc-page-grid__item ipc-page-grid__item--span-2'). 
    Here you explicitly say: I want to find a div with 
    attribute class = 'ipc-page-grid__item ipc-page-grid__item--span-2'.
    
    Since on each imdb page, there's only one div with class = 'lister-list', we can use find rather than find_all. 
    Find_all will return a list of div tags, while find() will return only one div.
   '''     
    movie_list = soup.find('div', 'ipc-page-grid__item ipc-page-grid__item--span-2') 
    # this div contains all the listed movies in the requested html web page string.
    
    list_movies = [] # initialize the function return value, which is a list of movies. 
                     # This list will contains the scraped data transformed to a structured format.
    
    # Using count track the number of movies processed. now it's 0 - No movie has been processed yet.
    count = 0
    
    # each movie listed in a div with attribute value 'ipc-metadata-list-summary-item'.
    divs=  movie_list.find_all('li','ipc-metadata-list-summary-item') # To find all the listed movies in the page.
    for d in divs:
        dict_each_movie = {}  # initialize the movie dictionary to store the movie information.

        # Pulling the movie_id
        try:
            movie_id= d.find('a', 'ipc-title-link-wrapper').attrs['href']
            movie_id= movie_id[7:16]
            
        except:
            movie_id=""
        finally:
            dict_each_movie["movie_id"] = movie_id
            print(movie_id)
            
        # Pulling the rank
        try:
            h3_element= d.find('h3', 'ipc-title__text')
            rank= h3_element.text.split('. ')[0]
            
        except:
            rank=""
        finally:
            dict_each_movie["rank"] = rank
            print(rank)
        
        # Pulling the title
        try:
            h3_element1= d.find('h3', 'ipc-title__text')
            title= h3_element1.text.split('. ')[1]
            
        except:
            title=""
        finally:
            dict_each_movie["title"] = title
            print(title)
            
        # Pulling the runtime
        try:
            runtime = ""
            runtime_element = d.find_all('span','dli-title-metadata-item')  # Fetch all span elements
            runtime = runtime_element[1].text.strip()
        except:
            runtime = ""  # Set to empty string if not found
        finally:
            dict_each_movie["runtime"] = runtime
            print("Runtime:", runtime)
            
        # Pulling the year
        try:
            year = ""
            year_element = d.find_all('span','dli-title-metadata-item')  # Fetch all span elements
            year = year_element[0].text.strip()
        except:
            year = ""  # Set to empty string if not found
        finally:
            dict_each_movie["year"] = year
            print("Year:", year)
        
        # Pulling the rating
          # the rating out of 10
        try:
            rating_element = d.find('span','ipc-rating-star--rating')
            rating = rating_element.text.strip()
            
        except:
            rating=""
        finally:
            dict_each_movie["rating"] = rating
            
        # Pulling the votes
        try:
            votes_element = d.find('span','ipc-rating-star--voteCount')
            votes = votes_element.text.strip().strip('()')
            
        except:
            votes=""
        finally:
            dict_each_movie["votes"] = votes
        
        list_movies.append(dict_each_movie)  # To add the movie information to the movies list.
        print(dict_each_movie)
        count +=1
        print('===============================')
        print()
        if count == num_of_m:
            break # to exit from the loop.

    return list_movies

# %% [markdown]
# ###  Call statement to scrap the TopVoted 500 movies
# ##### read_m_from_html_string(url,500)

# %%
url = "https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc"

Movies_list = read_m_from_html_string(url,500)  #to read the topVoted 500 movies
Movies_list
# Out:
# https://www.imdb.com/search/title/?title_type=feature&release_date=2018-01-01,2020-12-31&sort=num_votes,desc
# tt7286456
# 1
# Joker
# Runtime: 2h 2m
# Year: 2019
# {'movie_id': 'tt7286456', 'rank': '1', 'title': 'Joker', 'runtime': '2h 2m', 'year': '2019', 'rating': '8.4', 'votes': '1.6M'}
# ===============================
#
# tt4154796
# 2
# Avengers: Endgame
# Runtime: 3h 1m
# Year: 2019
# {'movie_id': 'tt4154796', 'rank': '2', 'title': 'Avengers: Endgame', 'runtime': '3h 1m', 'year': '2019', 'rating': '8.4', 'votes': '1.3M'}
# ===============================
#
# tt4154756
# 3
# Avengers: Infinity War
# Runtime: 2h 29m
# Year: 2018
# {'movie_id': 'tt4154756', 'rank': '3', 'title': 'Avengers: Infinity War', 'runtime': '2h 29m', 'year': '2018', 'rating': '8.4', 'votes': '1.2M'}
# ===============================
#
# tt6751668
# 4
# Parasite
# Runtime: 2h 12m
# Year: 2019
# {'movie_id': 'tt6751668', 'rank': '4', 'title': 'Parasite', 'runtime': '2h 12m', 'year': '2019', 'rating': '8.5', 'votes': '1M'}
# ===============================
#
# tt7131622
# 5
# Once Upon a Time..
# Runtime: 2h 41m
# Year: 2019
# {'movie_id': 'tt7131622', 'rank': '5', 'title': 'Once Upon a Time..', 'runtime': '2h 41m', 'year': '2019', 'rating': '7.6', 'votes': '878K'}
# ===============================
#
# tt1825683
# 6
# Black Panther
# Runtime: 2h 14m
# Year: 2018
# {'movie_id': 'tt1825683', 'rank': '6', 'title': 'Black Panther', 'runtime': '2h 14m', 'year': '2018', 'rating': '7.3', 'votes': '856K'}
# ===============================
#
# tt8946378
# 7
# Knives Out
# Runtime: 2h 10m
# Year: 2019
# {'movie_id': 'tt8946378', 'rank': '7', 'title': 'Knives Out', 'runtime': '2h 10m', 'year': '2019', 'rating': '7.9', 'votes': '796K'}
# ===============================
#
# tt8579674
# 8
# 1917
# Runtime: 1h 59m
# Year: 2019
# {'movie_id': 'tt8579674', 'rank': '8', 'title': '1917', 'runtime': '1h 59m', 'year': '2019', 'rating': '8.2', 'votes': '703K'}
# ===============================
#
# tt4633694
# 9
# Spider-Man: Into the Spider-Verse
# Runtime: 1h 57m
# Year: 2018
# {'movie_id': 'tt4633694', 'rank': '9', 'title': 'Spider-Man: Into the Spider-Verse', 'runtime': '1h 57m', 'year': '2018', 'rating': '8.4', 'votes': '702K'}
# ===============================
#
# tt5463162
# 10
# Deadpool 2
# Runtime: 1h 59m
# Year: 2018
# {'movie_id': 'tt5463162', 'rank': '10', 'title': 'Deadpool 2', 'runtime': '1h 59m', 'year': '2018', 'rating': '7.6', 'votes': '691K'}
# ===============================
#
# tt4154664
# 11
# Captain Marvel
# Runtime: 2h 3m
# Year: 2019
# {'movie_id': 'tt4154664', 'rank': '11', 'title': 'Captain Marvel', 'runtime': '2h 3m', 'year': '2019', 'rating': '6.8', 'votes': '624K'}
# ===============================
#
# tt6644200
# 12
# A Quiet Place
# Runtime: 1h 30m
# Year: 2018
# {'movie_id': 'tt6644200', 'rank': '12', 'title': 'A Quiet Place', 'runtime': '1h 30m', 'year': '2018', 'rating': '7.5', 'votes': '613K'}
# ===============================
#
# tt6723592
# 13
# Tenet
# Runtime: 2h 30m
# Year: 2020
# {'movie_id': 'tt6723592', 'rank': '13', 'title': 'Tenet', 'runtime': '2h 30m', 'year': '2020', 'rating': '7.3', 'votes': '612K'}
# ===============================
#
# tt1727824
# 14
# Bohemian Rhapsody
# Runtime: 2h 14m
# Year: 2018
# {'movie_id': 'tt1727824', 'rank': '14', 'title': 'Bohemian Rhapsody', 'runtime': '2h 14m', 'year': '2018', 'rating': '7.9', 'votes': '609K'}
# ===============================
#
# tt6966692
# 15
# Green Book
# Runtime: 2h 10m
# Year: 2018
# {'movie_id': 'tt6966692', 'rank': '15', 'title': 'Green Book', 'runtime': '2h 10m', 'year': '2018', 'rating': '8.2', 'votes': '605K'}
# ===============================
#
# tt6320628
# 16
# Spider-Man: Far from Home
# Runtime: 2h 9m
# Year: 2019
# {'movie_id': 'tt6320628', 'rank': '16', 'title': 'Spider-Man: Far from Home', 'runtime': '2h 9m', 'year': '2019', 'rating': '7.4', 'votes': '577K'}
# ===============================
#
# tt1270797
# 17
# Venom
# Runtime: 1h 52m
# Year: 2018
# {'movie_id': 'tt1270797', 'rank': '17', 'title': 'Venom', 'runtime': '1h 52m', 'year': '2018', 'rating': '6.6', 'votes': '560K'}
# ===============================
#
# tt1477834
# 18
# Aquaman
# Runtime: 2h 23m
# Year: 2018
# {'movie_id': 'tt1477834', 'rank': '18', 'title': 'Aquaman', 'runtime': '2h 23m', 'year': '2018', 'rating': '6.8', 'votes': '530K'}
# ===============================
#
# tt2527338
# 19
# Star Wars: Episode IX - The Rise of Skywalker
# Runtime: 2h 21m
# Year: 2019
# {'movie_id': 'tt2527338', 'rank': '19', 'title': 'Star Wars: Episode IX - The Rise of Skywalker', 'runtime': '2h 21m', 'year': '2019', 'rating': '6.4', 'votes': '506K'}
# ===============================
#
# tt1677720
# 20
# Ready Player One
# Runtime: 2h 20m
# Year: 2018
# {'movie_id': 'tt1677720', 'rank': '20', 'title': 'Ready Player One', 'runtime': '2h 20m', 'year': '2018', 'rating': '7.4', 'votes': '502K'}
# ===============================
#
# tt1950186
# 21
# Ford v Ferrari
# Runtime: 2h 32m
# Year: 2019
# {'movie_id': 'tt1950186', 'rank': '21', 'title': 'Ford v Ferrari', 'runtime': '2h 32m', 'year': '2019', 'rating': '8.1', 'votes': '501K'}
# ===============================
#
# tt5095030
# 22
# Ant-Man and the Wasp
# Runtime: 1h 58m
# Year: 2018
# {'movie_id': 'tt5095030', 'rank': '22', 'title': 'Ant-Man and the Wasp', 'runtime': '1h 58m', 'year': '2018', 'rating': '7.0', 'votes': '462K'}
# ===============================
#
# tt2584384
# 23
# Jojo Rabbit
# Runtime: 1h 48m
# Year: 2019
# {'movie_id': 'tt2584384', 'rank': '23', 'title': 'Jojo Rabbit', 'runtime': '1h 48m', 'year': '2019', 'rating': '7.9', 'votes': '455K'}
# ===============================
#
# tt1302006
# 24
# The Irishman
# Runtime: 3h 29m
# Year: 2019
# {'movie_id': 'tt1302006', 'rank': '24', 'title': 'The Irishman', 'runtime': '3h 29m', 'year': '2019', 'rating': '7.8', 'votes': '442K'}
# ===============================
#
# tt6146586
# 25
# John Wick: Chapter 3 - Parabellum
# Runtime: 2h 10m
# Year: 2019
# {'movie_id': 'tt6146586', 'rank': '25', 'title': 'John Wick: Chapter 3 - Parabellum', 'runtime': '2h 10m', 'year': '2019', 'rating': '7.4', 'votes': '440K'}
# ===============================
#
# tt8772262
# 26
# Midsommar
# Runtime: 2h 28m
# Year: 2019
# {'movie_id': 'tt8772262', 'rank': '26', 'title': 'Midsommar', 'runtime': '2h 28m', 'year': '2019', 'rating': '7.1', 'votes': '429K'}
# ===============================
#
# tt1517451
# 27
# A Star Is Born
# Runtime: 2h 16m
# Year: 2018
# {'movie_id': 'tt1517451', 'rank': '27', 'title': 'A Star Is Born', 'runtime': '2h 16m', 'year': '2018', 'rating': '7.6', 'votes': '429K'}
# ===============================
#
# tt8367814
# 28
# The Gentlemen
# Runtime: 1h 53m
# Year: 2019
# {'movie_id': 'tt8367814', 'rank': '28', 'title': 'The Gentlemen', 'runtime': '1h 53m', 'year': '2019', 'rating': '7.8', 'votes': '419K'}
# ===============================
#
# tt7784604
# 29
# Hereditary
# Runtime: 2h 7m
# Year: 2018
# {'movie_id': 'tt7784604', 'rank': '29', 'title': 'Hereditary', 'runtime': '2h 7m', 'year': '2018', 'rating': '7.3', 'votes': '401K'}
# ===============================
#
# tt2737304
# 30
# Bird Box
# Runtime: 2h 4m
# Year: 2018
# {'movie_id': 'tt2737304', 'rank': '30', 'title': 'Bird Box', 'runtime': '2h 4m', 'year': '2018', 'rating': '6.6', 'votes': '398K'}
# ===============================
#
# tt2948372
# 31
# Soul
# Runtime: 1h 40m
# Year: 2020
# {'movie_id': 'tt2948372', 'rank': '31', 'title': 'Soul', 'runtime': '1h 40m', 'year': '2020', 'rating': '8.0', 'votes': '395K'}
# ===============================
#
# tt0448115
# 32
# Shazam!
# Runtime: 2h 12m
# Year: 2019
# {'movie_id': 'tt0448115', 'rank': '32', 'title': 'Shazam!', 'runtime': '2h 12m', 'year': '2019', 'rating': '7.0', 'votes': '393K'}
# ===============================
#
# tt3778644
# 33
# Solo: A Star Wars Story
# Runtime: 2h 15m
# Year: 2018
# {'movie_id': 'tt3778644', 'rank': '33', 'title': 'Solo: A Star Wars Story', 'runtime': '2h 15m', 'year': '2018', 'rating': '6.9', 'votes': '388K'}
# ===============================
#
# tt4912910
# 34
# Mission: Impossible - Fallout
# Runtime: 2h 27m
# Year: 2018
# {'movie_id': 'tt4912910', 'rank': '34', 'title': 'Mission: Impossible - Fallout', 'runtime': '2h 27m', 'year': '2018', 'rating': '7.7', 'votes': '387K'}
# ===============================
#
# tt2798920
# 35
# Annihilation
# Runtime: 1h 55m
# Year: 2018
# {'movie_id': 'tt2798920', 'rank': '35', 'title': 'Annihilation', 'runtime': '1h 55m', 'year': '2018', 'rating': '6.8', 'votes': '371K'}
# ===============================
#
# tt6857112
# 36
# Us
# Runtime: 1h 56m
# Year: 2019
# {'movie_id': 'tt6857112', 'rank': '36', 'title': 'Us', 'runtime': '1h 56m', 'year': '2019', 'rating': '6.8', 'votes': '355K'}
# ===============================
#
# tt7653254
# 37
# Marriage Story
# Runtime: 2h 17m
# Year: 2019
# {'movie_id': 'tt7653254', 'rank': '37', 'title': 'Marriage Story', 'runtime': '2h 17m', 'year': '2019', 'rating': '7.9', 'votes': '354K'}
# ===============================
#
# tt4881806
# 38
# Jurassic World: Fallen Kingdom
# Runtime: 2h 8m
# Year: 2018
# {'movie_id': 'tt4881806', 'rank': '38', 'title': 'Jurassic World: Fallen Kingdom', 'runtime': '2h 8m', 'year': '2018', 'rating': '6.1', 'votes': '352K'}
# ===============================
#
# tt3606756
# 39
# Incredibles 2
# Runtime: 1h 58m
# Year: 2018
# {'movie_id': 'tt3606756', 'rank': '39', 'title': 'Incredibles 2', 'runtime': '1h 58m', 'year': '2018', 'rating': '7.5', 'votes': '342K'}
# ===============================
#
# tt5727208
# 40
# Uncut Gems
# Runtime: 2h 15m
# Year: 2019
# {'movie_id': 'tt5727208', 'rank': '40', 'title': 'Uncut Gems', 'runtime': '2h 15m', 'year': '2019', 'rating': '7.4', 'votes': '327K'}
# ===============================
#
# tt4123430
# 41
# Fantastic Beasts: The Crimes of Grindelwald
# Runtime: 2h 14m
# Year: 2018
# {'movie_id': 'tt4123430', 'rank': '41', 'title': 'Fantastic Beasts: The Crimes of Grindelwald', 'runtime': '2h 14m', 'year': '2018', 'rating': '6.5', 'votes': '315K'}
# ===============================
#
# tt7349950
# 42
# It Chapter Two
# Runtime: 2h 49m
# Year: 2019
# {'movie_id': 'tt7349950', 'rank': '42', 'title': 'It Chapter Two', 'runtime': '2h 49m', 'year': '2019', 'rating': '6.5', 'votes': '315K'}
# ===============================
#
# tt9243946
# 43
# El Camino
# Runtime: 2h 2m
# Year: 2019
# {'movie_id': 'tt9243946', 'rank': '43', 'title': 'El Camino', 'runtime': '2h 2m', 'year': '2019', 'rating': '7.3', 'votes': '305K'}
# ===============================
#
# tt0437086
# 44
# Alita: Battle Angel
# Runtime: 2h 2m
# Year: 2019
# {'movie_id': 'tt0437086', 'rank': '44', 'title': 'Alita: Battle Angel', 'runtime': '2h 2m', 'year': '2019', 'rating': '7.3', 'votes': '303K'}
# ===============================
#
# tt7126948
# 45
# Wonder Woman 1984
# Runtime: 2h 31m
# Year: 2020
# {'movie_id': 'tt7126948', 'rank': '45', 'title': 'Wonder Woman 1984', 'runtime': '2h 31m', 'year': '2020', 'rating': '5.4', 'votes': '297K'}
# ===============================
#
# tt7349662
# 46
# BlacKkKlansman
# Runtime: 2h 15m
# Year: 2018
# {'movie_id': 'tt7349662', 'rank': '46', 'title': 'BlacKkKlansman', 'runtime': '2h 15m', 'year': '2018', 'rating': '7.5', 'votes': '297K'}
# ===============================
#
# tt6139732
# 47
# Aladdin
# Runtime: 2h 8m
# Year: 2019
# {'movie_id': 'tt6139732', 'rank': '47', 'title': 'Aladdin', 'runtime': '2h 8m', 'year': '2019', 'rating': '6.9', 'votes': '297K'}
# ===============================
#
# tt8228288
# 48
# The Platform
# Runtime: 1h 34m
# Year: 2019
# {'movie_id': 'tt8228288', 'rank': '48', 'title': 'The Platform', 'runtime': '1h 34m', 'year': '2019', 'rating': '7.0', 'votes': '296K'}
# ===============================
#
# tt7975244
# 49
# Jumanji: The Next Level
# Runtime: 2h 3m
# Year: 2019
# {'movie_id': 'tt7975244', 'rank': '49', 'title': 'Jumanji: The Next Level', 'runtime': '2h 3m', 'year': '2019', 'rating': '6.7', 'votes': '295K'}
# ===============================
#
# tt8332922
# 50
# A Quiet Place Part II
# Runtime: 1h 37m
# Year: 2020
# {'movie_id': 'tt8332922', 'rank': '50', 'title': 'A Quiet Place Part II', 'runtime': '1h 37m', 'year': '2020', 'rating': '7.2', 'votes': '293K'}
# ===============================
#
# tt1979376
# 51
# Toy Story 4
# Runtime: 1h 40m
# Year: 2019
# {'movie_id': 'tt1979376', 'rank': '51', 'title': 'Toy Story 4', 'runtime': '1h 40m', 'year': '2019', 'rating': '7.6', 'votes': '290K'}
# ===============================
#
# tt6823368
# 52
# Glass
# Runtime: 2h 9m
# Year: 2019
# {'movie_id': 'tt6823368', 'rank': '52', 'title': 'Glass', 'runtime': '2h 9m', 'year': '2019', 'rating': '6.6', 'votes': '285K'}
# ===============================
#
# tt6105098
# 53
# The Lion King
# Runtime: 1h 58m
# Year: 2019
# {'movie_id': 'tt6105098', 'rank': '53', 'title': 'The Lion King', 'runtime': '1h 58m', 'year': '2019', 'rating': '6.8', 'votes': '273K'}
# ===============================
#
# tt8936646
# 54
# Extraction
# Runtime: 1h 56m
# Year: 2020
# {'movie_id': 'tt8936646', 'rank': '54', 'title': 'Extraction', 'runtime': '1h 56m', 'year': '2020', 'rating': '6.8', 'votes': '271K'}
# ===============================
#
# tt7713068
# 55
# Birds of Prey
# Runtime: 1h 49m
# Year: 2020
# {'movie_id': 'tt7713068', 'rank': '55', 'title': 'Birds of Prey', 'runtime': '1h 49m', 'year': '2020', 'rating': '6.1', 'votes': '270K'}
# ===============================
#
# tt7984734
# 56
# The Lighthouse
# Runtime: 1h 49m
# Year: 2019
# {'movie_id': 'tt7984734', 'rank': '56', 'title': 'The Lighthouse', 'runtime': '1h 49m', 'year': '2019', 'rating': '7.4', 'votes': '268K'}
# ===============================
#
# tt2935510
# 57
# Ad Astra
# Runtime: 2h 3m
# Year: 2019
# {'movie_id': 'tt2935510', 'rank': '57', 'title': 'Ad Astra', 'runtime': '2h 3m', 'year': '2019', 'rating': '6.5', 'votes': '266K'}
# ===============================
#
# tt1051906
# 58
# The Invisible Man
# Runtime: 2h 4m
# Year: 2020
# {'movie_id': 'tt1051906', 'rank': '58', 'title': 'The Invisible Man', 'runtime': '2h 4m', 'year': '2020', 'rating': '7.1', 'votes': '264K'}
# ===============================
#
# tt2704998
# 59
# Game Night
# Runtime: 1h 40m
# Year: 2018
# {'movie_id': 'tt2704998', 'rank': '59', 'title': 'Game Night', 'runtime': '1h 40m', 'year': '2018', 'rating': '6.9', 'votes': '261K'}
# ===============================
#
# tt3281548
# 60
# Little Women
# Runtime: 2h 15m
# Year: 2019
# {'movie_id': 'tt3281548', 'rank': '60', 'title': 'Little Women', 'runtime': '2h 15m', 'year': '2019', 'rating': '7.8', 'votes': '257K'}
# ===============================
#
# tt5164214
# 61
# Ocean's Eight
# Runtime: 1h 50m
# Year: 2018
# {'movie_id': 'tt5164214', 'rank': '61', 'title': "Ocean's Eight", 'runtime': '1h 50m', 'year': '2018', 'rating': '6.3', 'votes': '248K'}
# ===============================
#
# tt6806448
# 62
# Fast & Furious Presents: Hobbs & Shaw
# Runtime: 2h 17m
# Year: 2019
# {'movie_id': 'tt6806448', 'rank': '62', 'title': 'Fast & Furious Presents: Hobbs & Shaw', 'runtime': '2h 17m', 'year': '2019', 'rating': '6.5', 'votes': '243K'}
# ===============================
#
# tt5083738
# 63
# The Favourite
# Runtime: 1h 59m
# Year: 2018
# {'movie_id': 'tt5083738', 'rank': '63', 'title': 'The Favourite', 'runtime': '1h 59m', 'year': '2018', 'rating': '7.5', 'votes': '242K'}
# ===============================
#
# tt1365519
# 64
# Tomb Raider
# Runtime: 1h 59m
# Year: 2018
# {'movie_id': 'tt1365519', 'rank': '64', 'title': 'Tomb Raider', 'runtime': '1h 59m', 'year': '2018', 'rating': '6.3', 'votes': '231K'}
# ===============================
#
# tt7846844
# 65
# Enola Holmes
# Runtime: 2h 3m
# Year: 2020
# {'movie_id': 'tt7846844', 'rank': '65', 'title': 'Enola Holmes', 'runtime': '2h 3m', 'year': '2020', 'rating': '6.6', 'votes': '227K'}
# ===============================
#
# tt5606664
# 66
# Doctor Sleep
# Runtime: 2h 32m
# Year: 2019
# {'movie_id': 'tt5606664', 'rank': '66', 'title': 'Doctor Sleep', 'runtime': '2h 32m', 'year': '2019', 'rating': '7.3', 'votes': '227K'}
# ===============================
#
# tt9620292
# 67
# Promising Young Woman
# Runtime: 1h 53m
# Year: 2020
# {'movie_id': 'tt9620292', 'rank': '67', 'title': 'Promising Young Woman', 'runtime': '1h 53m', 'year': '2020', 'rating': '7.5', 'votes': '219K'}
# ===============================
#
# tt6499752
# 68
# Upgrade
# Runtime: 1h 40m
# Year: 2018
# {'movie_id': 'tt6499752', 'rank': '68', 'title': 'Upgrade', 'runtime': '1h 40m', 'year': '2018', 'rating': '7.5', 'votes': '216K'}
# ===============================
#
# tt3741700
# 69
# Godzilla: King of the Monsters
# Runtime: 2h 12m
# Year: 2019
# {'movie_id': 'tt3741700', 'rank': '69', 'title': 'Godzilla: King of the Monsters', 'runtime': '2h 12m', 'year': '2019', 'rating': '6.0', 'votes': '215K'}
# ===============================
#
# tt4779682
# 70
# The Meg
# Runtime: 1h 53m
# Year: 2018
# {'movie_id': 'tt4779682', 'rank': '70', 'title': 'The Meg', 'runtime': '1h 53m', 'year': '2018', 'rating': '5.7', 'votes': '214K'}
# ===============================
#
# tt6565702
# 71
# X-Men: Dark Phoenix
# Runtime: 1h 53m
# Year: 2019
# {'movie_id': 'tt6565702', 'rank': '71', 'title': 'X-Men: Dark Phoenix', 'runtime': '1h 53m', 'year': '2019', 'rating': '5.7', 'votes': '213K'}
# ===============================
#
# tt1560220
# 72
# Zombieland: Double Tap
# Runtime: 1h 39m
# Year: 2019
# {'movie_id': 'tt1560220', 'rank': '72', 'title': 'Zombieland: Double Tap', 'runtime': '1h 39m', 'year': '2019', 'rating': '6.7', 'votes': '210K'}
# ===============================
#
# tt3766354
# 73
# The Equalizer 2
# Runtime: 2h 1m
# Year: 2018
# {'movie_id': 'tt3766354', 'rank': '73', 'title': 'The Equalizer 2', 'runtime': '2h 1m', 'year': '2018', 'rating': '6.7', 'votes': '207K'}
# ===============================
#
# tt1213641
# 74
# First Man
# Runtime: 2h 21m
# Year: 2018
# {'movie_id': 'tt1213641', 'rank': '74', 'title': 'First Man', 'runtime': '2h 21m', 'year': '2018', 'rating': '7.3', 'votes': '207K'}
# ===============================
#
# tt2873282
# 75
# Red Sparrow
# Runtime: 2h 20m
# Year: 2018
# {'movie_id': 'tt2873282', 'rank': '75', 'title': 'Red Sparrow', 'runtime': '2h 20m', 'year': '2018', 'rating': '6.6', 'votes': '205K'}
# ===============================
#
# tt1028856
# 76
# Another Round
# Runtime: 1h 57m
# Year: 2020
# {'movie_id': 'tt1028856', 'rank': '76', 'title': 'Another Round', 'runtime': '1h 57m', 'year': '2020', 'rating': '7.7', 'votes': '204K'}
# ===============================
#
# tt1027238
# 77
# The Father
# Runtime: 1h 37m
# Year: 2020
# {'movie_id': 'tt1027238', 'rank': '77', 'title': 'The Father', 'runtime': '1h 37m', 'year': '2020', 'rating': '8.2', 'votes': '203K'}
# ===============================
#
# tt8106534
# 78
# 6 Underground
# Runtime: 2h 8m
# Year: 2019
# {'movie_id': 'tt8106534', 'rank': '78', 'title': '6 Underground', 'runtime': '2h 8m', 'year': '2019', 'rating': '6.1', 'votes': '202K'}
# ===============================
#
# tt4520988
# 79
# Frozen II
# Runtime: 1h 43m
# Year: 2019
# {'movie_id': 'tt4520988', 'rank': '79', 'title': 'Frozen II', 'runtime': '1h 43m', 'year': '2019', 'rating': '6.8', 'votes': '201K'}
# ===============================
#
# tt2066051
# 80
# Rocketman
# Runtime: 2h 1m
# Year: 2019
# {'movie_id': 'tt2066051', 'rank': '80', 'title': 'Rocketman', 'runtime': '2h 1m', 'year': '2019', 'rating': '7.3', 'votes': '200K'}
# ===============================
#
# tt6450804
# 81
# Terminator: Dark Fate
# Runtime: 2h 8m
# Year: 2019
# {'movie_id': 'tt6450804', 'rank': '81', 'title': 'Terminator: Dark Fate', 'runtime': '2h 8m', 'year': '2019', 'rating': '6.2', 'votes': '198K'}
# ===============================
#
# tt7798634
# 82
# Ready or Not
# Runtime: 1h 35m
# Year: 2019
# {'movie_id': 'tt7798634', 'rank': '82', 'title': 'Ready or Not', 'runtime': '1h 35m', 'year': '2019', 'rating': '6.9', 'votes': '198K'}
# ===============================
#
# tt4729430
# 83
# Klaus
# Runtime: 1h 36m
# Year: 2019
# {'movie_id': 'tt4729430', 'rank': '83', 'title': 'Klaus', 'runtime': '1h 36m', 'year': '2019', 'rating': '8.2', 'votes': '197K'}
# ===============================
#
# tt1070874
# 84
# The Trial of the Chicago 7
# Runtime: 2h 9m
# Year: 2020
# {'movie_id': 'tt1070874', 'rank': '84', 'title': 'The Trial of the Chicago 7', 'runtime': '2h 9m', 'year': '2020', 'rating': '7.7', 'votes': '197K'}
# ===============================
#
# tt3104988
# 85
# Crazy Rich Asians
# Runtime: 2h
# Year: 2018
# {'movie_id': 'tt3104988', 'rank': '85', 'title': 'Crazy Rich Asians', 'runtime': '2h', 'year': '2018', 'rating': '6.9', 'votes': '196K'}
# ===============================
#
# tt5104604
# 86
# Isle of Dogs
# Runtime: 1h 41m
# Year: 2018
# {'movie_id': 'tt5104604', 'rank': '86', 'title': 'Isle of Dogs', 'runtime': '1h 41m', 'year': '2018', 'rating': '7.8', 'votes': '196K'}
# ===============================
#
# tt4701182
# 87
# Bumblebee
# Runtime: 1h 54m
# Year: 2018
# {'movie_id': 'tt4701182', 'rank': '87', 'title': 'Bumblebee', 'runtime': '1h 54m', 'year': '2018', 'rating': '6.7', 'votes': '194K'}
# ===============================
#
# tt9484998
# 88
# Palm Springs
# Runtime: 1h 30m
# Year: 2020
# {'movie_id': 'tt9484998', 'rank': '88', 'title': 'Palm Springs', 'runtime': '1h 30m', 'year': '2020', 'rating': '7.4', 'votes': '192K'}
# ===============================
#
# tt2231461
# 89
# Rampage
# Runtime: 1h 47m
# Year: 2018
# {'movie_id': 'tt2231461', 'rank': '89', 'title': 'Rampage', 'runtime': '1h 47m', 'year': '2018', 'rating': '6.1', 'votes': '190K'}
# ===============================
#
# tt5848272
# 90
# Ralph Breaks the Internet
# Runtime: 1h 52m
# Year: 2018
# {'movie_id': 'tt5848272', 'rank': '90', 'title': 'Ralph Breaks the Internet', 'runtime': '1h 52m', 'year': '2018', 'rating': '7.0', 'votes': '190K'}
# ===============================
#
# tt9770150
# 91
# Nomadland
# Runtime: 1h 47m
# Year: 2020
# {'movie_id': 'tt9770150', 'rank': '91', 'title': 'Nomadland', 'runtime': '1h 47m', 'year': '2020', 'rating': '7.3', 'votes': '188K'}
# ===============================
#
# tt7556122
# 92
# The Old Guard
# Runtime: 2h 5m
# Year: 2020
# {'movie_id': 'tt7556122', 'rank': '92', 'title': 'The Old Guard', 'runtime': '2h 5m', 'year': '2020', 'rating': '6.7', 'votes': '188K'}
# ===============================
#
# tt5884052
# 93
# Pokémon: Detective Pikachu
# Runtime: 1h 44m
# Year: 2019
# {'movie_id': 'tt5884052', 'rank': '93', 'title': 'Pokémon: Detective Pikachu', 'runtime': '1h 44m', 'year': '2019', 'rating': '6.5', 'votes': '187K'}
# ===============================
#
# tt1502397
# 94
# Bad Boys for Life
# Runtime: 2h 4m
# Year: 2020
# {'movie_id': 'tt1502397', 'rank': '94', 'title': 'Bad Boys for Life', 'runtime': '2h 4m', 'year': '2020', 'rating': '6.5', 'votes': '186K'}
# ===============================
#
# tt7668870
# 95
# Searching
# Runtime: 1h 42m
# Year: 2018
# {'movie_id': 'tt7668870', 'rank': '95', 'title': 'Searching', 'runtime': '1h 42m', 'year': '2018', 'rating': '7.6', 'votes': '183K'}
# ===============================
#
# tt5814060
# 96
# The Nun
# Runtime: 1h 36m
# Year: 2018
# {'movie_id': 'tt5814060', 'rank': '96', 'title': 'The Nun', 'runtime': '1h 36m', 'year': '2018', 'rating': '5.3', 'votes': '177K'}
# ===============================
#
# tt1502407
# 97
# Halloween
# Runtime: 1h 46m
# Year: 2018
# {'movie_id': 'tt1502407', 'rank': '97', 'title': 'Halloween', 'runtime': '1h 46m', 'year': '2018', 'rating': '6.5', 'votes': '176K'}
# ===============================
#
# tt7146812
# 98
# Onward
# Runtime: 1h 42m
# Year: 2020
# {'movie_id': 'tt7146812', 'rank': '98', 'title': 'Onward', 'runtime': '1h 42m', 'year': '2020', 'rating': '7.4', 'votes': '175K'}
# ===============================
#
# tt1618434
# 99
# Murder Mystery
# Runtime: 1h 37m
# Year: 2019
# {'movie_id': 'tt1618434', 'rank': '99', 'title': 'Murder Mystery', 'runtime': '1h 37m', 'year': '2019', 'rating': '6.1', 'votes': '175K'}
# ===============================
#
# tt5052474
# 100
# Sicario: Day of the Soldado
# Runtime: 2h 2m
# Year: 2018
# {'movie_id': 'tt5052474', 'rank': '100', 'title': 'Sicario: Day of the Soldado', 'runtime': '2h 2m', 'year': '2018', 'rating': '7.1', 'votes': '173K'}
# ===============================
#
# tt8079248
# 101
# Yesterday
# Runtime: 1h 56m
# Year: 2019
# {'movie_id': 'tt8079248', 'rank': '101', 'title': 'Yesterday', 'runtime': '1h 56m', 'year': '2019', 'rating': '6.8', 'votes': '173K'}
# ===============================
#
# tt6412452
# 102
# The Ballad of Buster Scruggs
# Runtime: 2h 13m
# Year: 2018
# {'movie_id': 'tt6412452', 'rank': '102', 'title': 'The Ballad of Buster Scruggs', 'runtime': '2h 13m', 'year': '2018', 'rating': '7.2', 'votes': '172K'}
# ===============================
#
# tt6155172
# 103
# Roma
# Runtime: 2h 15m
# Year: 2018
# {'movie_id': 'tt6155172', 'rank': '103', 'title': 'Roma', 'runtime': '2h 15m', 'year': '2018', 'rating': '7.7', 'votes': '172K'}
# ===============================
#
# tt4500922
# 104
# Maze Runner: The Death Cure
# Runtime: 2h 23m
# Year: 2018
# {'movie_id': 'tt4500922', 'rank': '104', 'title': 'Maze Runner: The Death Cure', 'runtime': '2h 23m', 'year': '2018', 'rating': '6.3', 'votes': '172K'}
# ===============================
#
# tt7040874
# 105
# A Simple Favor
# Runtime: 1h 57m
# Year: 2018
# {'movie_id': 'tt7040874', 'rank': '105', 'title': 'A Simple Favor', 'runtime': '1h 57m', 'year': '2018', 'rating': '6.8', 'votes': '170K'}
# ===============================
#
# tt6628394
# 106
# Bad Times at the El Royale
# Runtime: 2h 21m
# Year: 2018
# {'movie_id': 'tt6628394', 'rank': '106', 'title': 'Bad Times at the El Royale', 'runtime': '2h 21m', 'year': '2018', 'rating': '7.1', 'votes': '169K'}
# ===============================
#
# tt3794354
# 107
# Sonic the Hedgehog
# Runtime: 1h 39m
# Year: 2020
# {'movie_id': 'tt3794354', 'rank': '107', 'title': 'Sonic the Hedgehog', 'runtime': '1h 39m', 'year': '2020', 'rating': '6.5', 'votes': '166K'}
# ===============================
#
# tt6266538
# 108
# Vice
# Runtime: 2h 12m
# Year: 2018
# {'movie_id': 'tt6266538', 'rank': '108', 'title': 'Vice', 'runtime': '2h 12m', 'year': '2018', 'rating': '7.2', 'votes': '166K'}
# ===============================
#
# tt4566758
# 109
# Mulan
# Runtime: 1h 55m
# Year: 2020
# {'movie_id': 'tt4566758', 'rank': '109', 'title': 'Mulan', 'runtime': '1h 55m', 'year': '2020', 'rating': '5.8', 'votes': '162K'}
# ===============================
#
# tt6343314
# 110
# Creed II
# Runtime: 2h 10m
# Year: 2018
# {'movie_id': 'tt6343314', 'rank': '110', 'title': 'Creed II', 'runtime': '2h 10m', 'year': '2018', 'rating': '7.1', 'votes': '159K'}
# ===============================
#
# tt7984766
# 111
# The King
# Runtime: 2h 20m
# Year: 2019
# {'movie_id': 'tt7984766', 'rank': '111', 'title': 'The King', 'runtime': '2h 20m', 'year': '2019', 'rating': '7.3', 'votes': '159K'}
# ===============================
#
# tt7395114
# 112
# The Devil All the Time
# Runtime: 2h 18m
# Year: 2020
# {'movie_id': 'tt7395114', 'rank': '112', 'title': 'The Devil All the Time', 'runtime': '2h 18m', 'year': '2020', 'rating': '7.1', 'votes': '157K'}
# ===============================
#
# tt1314396
# 113
# Borat Subsequent Moviefilm
# Runtime: 1h 35m
# Year: 2020
# {'movie_id': 'tt1314396', 'rank': '113', 'title': 'Borat Subsequent Moviefilm', 'runtime': '1h 35m', 'year': '2020', 'rating': '6.6', 'votes': '157K'}
# ===============================
#
# tt2386490
# 114
# How to Train Your Dragon: The Hidden World
# Runtime: 1h 44m
# Year: 2019
# {'movie_id': 'tt2386490', 'rank': '114', 'title': 'How to Train Your Dragon: The Hidden World', 'runtime': '1h 44m', 'year': '2019', 'rating': '7.4', 'votes': '157K'}
# ===============================
#
# tt7959026
# 115
# The Mule
# Runtime: 1h 56m
# Year: 2018
# {'movie_id': 'tt7959026', 'rank': '115', 'title': 'The Mule', 'runtime': '1h 56m', 'year': '2018', 'rating': '7.0', 'votes': '157K'}
# ===============================
#
# tt5363618
# 116
# Sound of Metal
# Runtime: 2h
# Year: 2019
# {'movie_id': 'tt5363618', 'rank': '116', 'title': 'Sound of Metal', 'runtime': '2h', 'year': '2019', 'rating': '7.7', 'votes': '155K'}
# ===============================
#
# tt2854926
# 117
# Tag
# Runtime: 1h 40m
# Year: 2018
# {'movie_id': 'tt2854926', 'rank': '117', 'title': 'Tag', 'runtime': '1h 40m', 'year': '2018', 'rating': '6.5', 'votes': '151K'}
# ===============================
#
# tt2283336
# 118
# Men in Black: International
# Runtime: 1h 54m
# Year: 2019
# {'movie_id': 'tt2283336', 'rank': '118', 'title': 'Men in Black: International', 'runtime': '1h 54m', 'year': '2019', 'rating': '5.6', 'votes': '151K'}
# ===============================
#
# tt9893250
# 119
# I Care a Lot
# Runtime: 1h 58m
# Year: 2020
# {'movie_id': 'tt9893250', 'rank': '119', 'title': 'I Care a Lot', 'runtime': '1h 58m', 'year': '2020', 'rating': '6.4', 'votes': '150K'}
# ===============================
#
# tt3829266
# 120
# The Predator
# Runtime: 1h 47m
# Year: 2018
# {'movie_id': 'tt3829266', 'rank': '120', 'title': 'The Predator', 'runtime': '1h 47m', 'year': '2018', 'rating': '5.3', 'votes': '150K'}
# ===============================
#
# tt1488606
# 121
# Triple Frontier
# Runtime: 2h 5m
# Year: 2019
# {'movie_id': 'tt1488606', 'rank': '121', 'title': 'Triple Frontier', 'runtime': '2h 5m', 'year': '2019', 'rating': '6.5', 'votes': '150K'}
# ===============================
#
# tt2222042
# 122
# Love and Monsters
# Runtime: 1h 49m
# Year: 2020
# {'movie_id': 'tt2222042', 'rank': '122', 'title': 'Love and Monsters', 'runtime': '1h 49m', 'year': '2020', 'rating': '6.9', 'votes': '150K'}
# ===============================
#
# tt5886046
# 123
# Escape Room
# Runtime: 1h 39m
# Year: 2019
# {'movie_id': 'tt5886046', 'rank': '123', 'title': 'Escape Room', 'runtime': '1h 39m', 'year': '2019', 'rating': '6.4', 'votes': '147K'}
# ===============================
#
# tt1571234
# 124
# Mortal Engines
# Runtime: 2h 8m
# Year: 2018
# {'movie_id': 'tt1571234', 'rank': '124', 'title': 'Mortal Engines', 'runtime': '2h 8m', 'year': '2018', 'rating': '6.1', 'votes': '145K'}
# ===============================
#
# tt7737786
# 125
# Greenland
# Runtime: 1h 59m
# Year: 2020
# {'movie_id': 'tt7737786', 'rank': '125', 'title': 'Greenland', 'runtime': '1h 59m', 'year': '2020', 'rating': '6.4', 'votes': '141K'}
# ===============================
#
# tt9495224
# 126
# Black Mirror: Bandersnatch
# Runtime: 1h 30m
# Year: 2018
# {'movie_id': 'tt9495224', 'rank': '126', 'title': 'Black Mirror: Bandersnatch', 'runtime': '1h 30m', 'year': '2018', 'rating': '7.1', 'votes': '138K'}
# ===============================
#
# tt5758778
# 127
# Skyscraper
# Runtime: 1h 42m
# Year: 2018
# {'movie_id': 'tt5758778', 'rank': '127', 'title': 'Skyscraper', 'runtime': '1h 42m', 'year': '2018', 'rating': '5.8', 'votes': '138K'}
# ===============================
#
# tt8110330
# 128
# Dil Bechara
# Runtime: 1h 41m
# Year: 2020
# {'movie_id': 'tt8110330', 'rank': '128', 'title': 'Dil Bechara', 'runtime': '1h 41m', 'year': '2020', 'rating': '8.3', 'votes': '136K'}
# ===============================
#
# tt8404614
# 129
# The Two Popes
# Runtime: 2h 5m
# Year: 2019
# {'movie_id': 'tt8404614', 'rank': '129', 'title': 'The Two Popes', 'runtime': '2h 5m', 'year': '2019', 'rating': '7.6', 'votes': '135K'}
# ===============================
#
# tt1489887
# 130
# Booksmart
# Runtime: 1h 42m
# Year: 2019
# {'movie_id': 'tt1489887', 'rank': '130', 'title': 'Booksmart', 'runtime': '1h 42m', 'year': '2019', 'rating': '7.1', 'votes': '134K'}
# ===============================
#
# tt8244784
# 131
# The Hunt
# Runtime: 1h 30m
# Year: 2020
# {'movie_id': 'tt8244784', 'rank': '131', 'title': 'The Hunt', 'runtime': '1h 30m', 'year': '2020', 'rating': '6.6', 'votes': '133K'}
# ===============================
#
# tt2557478
# 132
# Pacific Rim: Uprising
# Runtime: 1h 51m
# Year: 2018
# {'movie_id': 'tt2557478', 'rank': '132', 'title': 'Pacific Rim: Uprising', 'runtime': '1h 51m', 'year': '2018', 'rating': '5.6', 'votes': '130K'}
# ===============================
#
# tt6394270
# 133
# Bombshell
# Runtime: 1h 49m
# Year: 2019
# {'movie_id': 'tt6394270', 'rank': '133', 'title': 'Bombshell', 'runtime': '1h 49m', 'year': '2019', 'rating': '6.8', 'votes': '130K'}
# ===============================
#
# tt5164432
# 134
# Love, Simon
# Runtime: 1h 50m
# Year: 2018
# {'movie_id': 'tt5164432', 'rank': '134', 'title': 'Love, Simon', 'runtime': '1h 50m', 'year': '2018', 'rating': '7.5', 'votes': '129K'}
# ===============================
#
# tt3846674
# 135
# To All the Boys I've Loved Before
# Runtime: 1h 39m
# Year: 2018
# {'movie_id': 'tt3846674', 'rank': '135', 'title': "To All the Boys I've Loved Before", 'runtime': '1h 39m', 'year': '2018', 'rating': '7.0', 'votes': '128K'}
# ===============================
#
# tt1590193
# 136
# The Commuter
# Runtime: 1h 44m
# Year: 2018
# {'movie_id': 'tt1590193', 'rank': '136', 'title': 'The Commuter', 'runtime': '1h 44m', 'year': '2018', 'rating': '6.3', 'votes': '128K'}
# ===============================
#
# tt1259528
# 137
# Den of Thieves
# Runtime: 2h 20m
# Year: 2018
# {'movie_id': 'tt1259528', 'rank': '137', 'title': 'Den of Thieves', 'runtime': '2h 20m', 'year': '2018', 'rating': '7.0', 'votes': '127K'}
# ===============================
#
# tt1018951
# 138
# Soorarai Pottru
# Runtime: 2h 33m
# Year: 2020
# {'movie_id': 'tt1018951', 'rank': '138', 'title': 'Soorarai Pottru', 'runtime': '2h 33m', 'year': '2020', 'rating': '8.7', 'votes': '126K'}
# ===============================
#
# tt1025100
# 139
# Gemini Man
# Runtime: 1h 57m
# Year: 2019
# {'movie_id': 'tt1025100', 'rank': '139', 'title': 'Gemini Man', 'runtime': '1h 57m', 'year': '2019', 'rating': '5.7', 'votes': '125K'}
# ===============================
#
# tt7401588
# 140
# Instant Family
# Runtime: 1h 58m
# Year: 2018
# {'movie_id': 'tt7401588', 'rank': '140', 'title': 'Instant Family', 'runtime': '1h 58m', 'year': '2018', 'rating': '7.3', 'votes': '124K'}
# ===============================
#
# tt2139881
# 141
# Long Shot
# Runtime: 2h 5m
# Year: 2019
# {'movie_id': 'tt2139881', 'rank': '141', 'title': 'Long Shot', 'runtime': '2h 5m', 'year': '2019', 'rating': '6.8', 'votes': '124K'}
# ===============================
#
# tt4777008
# 142
# Maleficent: Mistress of Evil
# Runtime: 1h 59m
# Year: 2019
# {'movie_id': 'tt4777008', 'rank': '142', 'title': 'Maleficent: Mistress of Evil', 'runtime': '1h 59m', 'year': '2019', 'rating': '6.6', 'votes': '122K'}
# ===============================
#
# tt8503618
# 143
# Hamilton
# Runtime: 2h 40m
# Year: 2020
# {'movie_id': 'tt8503618', 'rank': '143', 'title': 'Hamilton', 'runtime': '2h 40m', 'year': '2020', 'rating': '8.3', 'votes': '120K'}
# ===============================
#
# tt6048922
# 144
# Greyhound
# Runtime: 1h 31m
# Year: 2020
# {'movie_id': 'tt6048922', 'rank': '144', 'title': 'Greyhound', 'runtime': '1h 31m', 'year': '2020', 'rating': '7.0', 'votes': '119K'}
# ===============================
#
# tt2548396
# 145
# The Cloverfield Paradox
# Runtime: 1h 42m
# Year: 2018
# {'movie_id': 'tt2548396', 'rank': '145', 'title': 'The Cloverfield Paradox', 'runtime': '1h 42m', 'year': '2018', 'rating': '5.5', 'votes': '115K'}
# ===============================
#
# tt8613070
# 146
# Portrait of a Lady on Fire
# Runtime: 2h 2m
# Year: 2019
# {'movie_id': 'tt8613070', 'rank': '146', 'title': 'Portrait of a Lady on Fire', 'runtime': '2h 2m', 'year': '2019', 'rating': '8.1', 'votes': '114K'}
# ===============================
#
# tt6189022
# 147
# Angel Has Fallen
# Runtime: 2h 1m
# Year: 2019
# {'movie_id': 'tt6189022', 'rank': '147', 'title': 'Angel Has Fallen', 'runtime': '2h 1m', 'year': '2019', 'rating': '6.4', 'votes': '114K'}
# ===============================
#
# tt6911608
# 148
# Mamma Mia! Here We Go Again
# Runtime: 1h 54m
# Year: 2018
# {'movie_id': 'tt6911608', 'rank': '148', 'title': 'Mamma Mia! Here We Go Again', 'runtime': '1h 54m', 'year': '2018', 'rating': '6.6', 'votes': '113K'}
# ===============================
#
# tt1206885
# 149
# Rambo: Last Blood
# Runtime: 1h 29m
# Year: 2019
# {'movie_id': 'tt1206885', 'rank': '149', 'title': 'Rambo: Last Blood', 'runtime': '1h 29m', 'year': '2019', 'rating': '6.1', 'votes': '113K'}
# ===============================
#
# tt9071322
# 150
# Dark Waters
# Runtime: 2h 6m
# Year: 2019
# {'movie_id': 'tt9071322', 'rank': '150', 'title': 'Dark Waters', 'runtime': '2h 6m', 'year': '2019', 'rating': '7.6', 'votes': '111K'}
# ===============================
#
# tt7752126
# 151
# Brightburn
# Runtime: 1h 30m
# Year: 2019
# {'movie_id': 'tt7752126', 'rank': '151', 'title': 'Brightburn', 'runtime': '1h 30m', 'year': '2019', 'rating': '6.1', 'votes': '111K'}
# ===============================
#
# tt8267604
# 152
# Capernaum
# Runtime: 2h 6m
# Year: 2018
# {'movie_id': 'tt8267604', 'rank': '152', 'title': 'Capernaum', 'runtime': '2h 6m', 'year': '2018', 'rating': '8.4', 'votes': '111K'}
# ===============================
#
# tt4364194
# 153
# The Peanut Butter Falcon
# Runtime: 1h 37m
# Year: 2019
# {'movie_id': 'tt4364194', 'rank': '153', 'title': 'The Peanut Butter Falcon', 'runtime': '1h 37m', 'year': '2019', 'rating': '7.6', 'votes': '110K'}
# ===============================
#
# tt5503686
# 154
# Hustlers
# Runtime: 1h 50m
# Year: 2019
# {'movie_id': 'tt5503686', 'rank': '154', 'title': 'Hustlers', 'runtime': '1h 50m', 'year': '2019', 'rating': '6.3', 'votes': '109K'}
# ===============================
#
# tt4530422
# 155
# Overlord
# Runtime: 1h 50m
# Year: 2018
# {'movie_id': 'tt4530422', 'rank': '155', 'title': 'Overlord', 'runtime': '1h 50m', 'year': '2018', 'rating': '6.6', 'votes': '109K'}
# ===============================
#
# tt2481498
# 156
# Extremely Wicked, Shockingly Evil and Vile
# Runtime: 1h 50m
# Year: 2019
# {'movie_id': 'tt2481498', 'rank': '156', 'title': 'Extremely Wicked, Shockingly Evil and Vile', 'runtime': '1h 50m', 'year': '2019', 'rating': '6.7', 'votes': '107K'}
# ===============================
#
# tt1860242
# 157
# The Highwaymen
# Runtime: 2h 12m
# Year: 2019
# {'movie_id': 'tt1860242', 'rank': '157', 'title': 'The Highwaymen', 'runtime': '2h 12m', 'year': '2019', 'rating': '6.9', 'votes': '107K'}
# ===============================
#
# tt1226837
# 158
# Beautiful Boy
# Runtime: 2h
# Year: 2018
# {'movie_id': 'tt1226837', 'rank': '158', 'title': 'Beautiful Boy', 'runtime': '2h', 'year': '2018', 'rating': '7.4', 'votes': '107K'}
# ===============================
#
# tt8108198
# 159
# Andhadhun
# Runtime: 2h 19m
# Year: 2018
# {'movie_id': 'tt8108198', 'rank': '159', 'title': 'Andhadhun', 'runtime': '2h 19m', 'year': '2018', 'rating': '8.2', 'votes': '106K'}
# ===============================
#
# tt4218572
# 160
# Widows
# Runtime: 2h 9m
# Year: 2018
# {'movie_id': 'tt4218572', 'rank': '160', 'title': 'Widows', 'runtime': '2h 9m', 'year': '2018', 'rating': '6.8', 'votes': '106K'}
# ===============================
#
# tt8580274
# 161
# Eurovision Song Contest: The Story of Fire Saga
# Runtime: 2h 3m
# Year: 2020
# {'movie_id': 'tt8580274', 'rank': '161', 'title': 'Eurovision Song Contest: The Story of Fire Saga', 'runtime': '2h 3m', 'year': '2020', 'rating': '6.5', 'votes': '104K'}
# ===============================
#
# tt2274648
# 162
# Hellboy
# Runtime: 2h
# Year: 2019
# {'movie_id': 'tt2274648', 'rank': '162', 'title': 'Hellboy', 'runtime': '2h', 'year': '2019', 'rating': '5.3', 'votes': '103K'}
# ===============================
#
# tt7939766
# 163
# I'm Thinking of Ending Things
# Runtime: 2h 14m
# Year: 2020
# {'movie_id': 'tt7939766', 'rank': '163', 'title': "I'm Thinking of Ending Things", 'runtime': '2h 14m', 'year': '2020', 'rating': '6.5', 'votes': '103K'}
# ===============================
#
# tt7838252
# 164
# K.G.F: Chapter 1
# Runtime: 2h 34m
# Year: 2018
# {'movie_id': 'tt7838252', 'rank': '164', 'title': 'K.G.F: Chapter 1', 'runtime': '2h 34m', 'year': '2018', 'rating': '8.2', 'votes': '102K'}
# ===============================
#
# tt6292852
# 165
# I Am Mother
# Runtime: 1h 53m
# Year: 2019
# {'movie_id': 'tt6292852', 'rank': '165', 'title': 'I Am Mother', 'runtime': '1h 53m', 'year': '2019', 'rating': '6.7', 'votes': '101K'}
# ===============================
#
# tt1088616
# 166
# 365 Days
# Runtime: 1h 54m
# Year: 2020
# {'movie_id': 'tt1088616', 'rank': '166', 'title': '365 Days', 'runtime': '1h 54m', 'year': '2020', 'rating': '3.3', 'votes': '101K'}
# ===============================
#
# tt4139588
# 167
# Polar
# Runtime: 1h 58m
# Year: 2019
# {'movie_id': 'tt4139588', 'rank': '167', 'title': 'Polar', 'runtime': '1h 58m', 'year': '2019', 'rating': '6.3', 'votes': '101K'}
# ===============================
#
# tt5774060
# 168
# Underwater
# Runtime: 1h 35m
# Year: 2020
# {'movie_id': 'tt5774060', 'rank': '168', 'title': 'Underwater', 'runtime': '1h 35m', 'year': '2020', 'rating': '5.9', 'votes': '101K'}
# ===============================
#
# tt1063345
# 169
# Minari
# Runtime: 1h 55m
# Year: 2020
# {'movie_id': 'tt1063345', 'rank': '169', 'title': 'Minari', 'runtime': '1h 55m', 'year': '2020', 'rating': '7.4', 'votes': '101K'}
# ===============================
#
# tt8633478
# 170
# Run
# Runtime: 1h 30m
# Year: 2020
# {'movie_id': 'tt8633478', 'rank': '170', 'title': 'Run', 'runtime': '1h 30m', 'year': '2020', 'rating': '6.7', 'votes': '101K'}
# ===============================
#
# tt8629748
# 171
# Spenser Confidential
# Runtime: 1h 51m
# Year: 2020
# {'movie_id': 'tt8629748', 'rank': '171', 'title': 'Spenser Confidential', 'runtime': '1h 51m', 'year': '2020', 'rating': '6.2', 'votes': '101K'}
# ===============================
#
# tt0837563
# 172
# Pet Sematary
# Runtime: 1h 40m
# Year: 2019
# {'movie_id': 'tt0837563', 'rank': '172', 'title': 'Pet Sematary', 'runtime': '1h 40m', 'year': '2019', 'rating': '5.7', 'votes': '100K'}
# ===============================
#
# tt3513548
# 173
# Richard Jewell
# Runtime: 2h 11m
# Year: 2019
# {'movie_id': 'tt3513548', 'rank': '173', 'title': 'Richard Jewell', 'runtime': '2h 11m', 'year': '2019', 'rating': '7.5', 'votes': '100K'}
# ===============================
#
# tt7456310
# 174
# Anna
# Runtime: 1h 58m
# Year: 2019
# {'movie_id': 'tt7456310', 'rank': '174', 'title': 'Anna', 'runtime': '1h 58m', 'year': '2019', 'rating': '6.6', 'votes': '100K'}
# ===============================
#
# tt7550000
# 175
# Project Power
# Runtime: 1h 53m
# Year: 2020
# {'movie_id': 'tt7550000', 'rank': '175', 'title': 'Project Power', 'runtime': '1h 53m', 'year': '2020', 'rating': '6.0', 'votes': '99K'}
# ===============================
#
# tt4332232
# 176
# Fractured
# Runtime: 1h 39m
# Year: 2019
# {'movie_id': 'tt4332232', 'rank': '176', 'title': 'Fractured', 'runtime': '1h 39m', 'year': '2019', 'rating': '6.5', 'votes': '99K'}
# ===============================
#
# tt6878306
# 177
# News of the World
# Runtime: 1h 58m
# Year: 2020
# {'movie_id': 'tt6878306', 'rank': '177', 'title': 'News of the World', 'runtime': '1h 58m', 'year': '2020', 'rating': '6.8', 'votes': '97K'}
# ===============================
#
# tt6924650
# 178
# Midway
# Runtime: 2h 18m
# Year: 2019
# {'movie_id': 'tt6924650', 'rank': '178', 'title': 'Midway', 'runtime': '2h 18m', 'year': '2019', 'rating': '6.7', 'votes': '97K'}
# ===============================
#
# tt1034415
# 179
# Suspiria
# Runtime: 2h 32m
# Year: 2018
# {'movie_id': 'tt1034415', 'rank': '179', 'title': 'Suspiria', 'runtime': '2h 32m', 'year': '2018', 'rating': '6.7', 'votes': '97K'}
# ===============================
#
# tt7886848
# 180
# Sadak 2
# Runtime: 2h 13m
# Year: 2020
# {'movie_id': 'tt7886848', 'rank': '180', 'title': 'Sadak 2', 'runtime': '2h 13m', 'year': '2020', 'rating': '1.2', 'votes': '97K'}
# ===============================
#
# tt8364368
# 181
# Crawl
# Runtime: 1h 27m
# Year: 2019
# {'movie_id': 'tt8364368', 'rank': '181', 'title': 'Crawl', 'runtime': '1h 27m', 'year': '2019', 'rating': '6.1', 'votes': '97K'}
# ===============================
#
# tt5028340
# 182
# Mary Poppins Returns
# Runtime: 2h 10m
# Year: 2018
# {'movie_id': 'tt5028340', 'rank': '182', 'title': 'Mary Poppins Returns', 'runtime': '2h 10m', 'year': '2018', 'rating': '6.7', 'votes': '97K'}
# ===============================
#
# tt3799232
# 183
# The Kissing Booth
# Runtime: 1h 45m
# Year: 2018
# {'movie_id': 'tt3799232', 'rank': '183', 'title': 'The Kissing Booth', 'runtime': '1h 45m', 'year': '2018', 'rating': '5.9', 'votes': '96K'}
# ===============================
#
# tt4003440
# 184
# The House That Jack Built
# Runtime: 2h 32m
# Year: 2018
# {'movie_id': 'tt4003440', 'rank': '184', 'title': 'The House That Jack Built', 'runtime': '2h 32m', 'year': '2018', 'rating': '6.8', 'votes': '96K'}
# ===============================
#
# tt1413492
# 185
# 12 Strong
# Runtime: 2h 10m
# Year: 2018
# {'movie_id': 'tt1413492', 'rank': '185', 'title': '12 Strong', 'runtime': '2h 10m', 'year': '2018', 'rating': '6.5', 'votes': '94K'}
# ===============================
#
# tt2709692
# 186
# The Grinch
# Runtime: 1h 25m
# Year: 2018
# {'movie_id': 'tt2709692', 'rank': '186', 'title': 'The Grinch', 'runtime': '1h 25m', 'year': '2018', 'rating': '6.4', 'votes': '94K'}
# ===============================
#
# tt4682266
# 187
# The New Mutants
# Runtime: 1h 34m
# Year: 2020
# {'movie_id': 'tt4682266', 'rank': '187', 'title': 'The New Mutants', 'runtime': '1h 34m', 'year': '2020', 'rating': '5.3', 'votes': '94K'}
# ===============================
#
# tt6998518
# 188
# Mandy
# Runtime: 2h 1m
# Year: 2018
# {'movie_id': 'tt6998518', 'rank': '188', 'title': 'Mandy', 'runtime': '2h 1m', 'year': '2018', 'rating': '6.5', 'votes': '93K'}
# ===============================
#
# tt8623904
# 189
# Last Christmas
# Runtime: 1h 43m
# Year: 2019
# {'movie_id': 'tt8623904', 'rank': '189', 'title': 'Last Christmas', 'runtime': '1h 43m', 'year': '2019', 'rating': '6.5', 'votes': '92K'}
# ===============================
#
# tt1146482
# 190
# The Social Dilemma
# Runtime: 1h 34m
# Year: 2020
# {'movie_id': 'tt1146482', 'rank': '190', 'title': 'The Social Dilemma', 'runtime': '1h 34m', 'year': '2020', 'rating': '7.6', 'votes': '91K'}
# ===============================
#
# tt8350360
# 191
# Annabelle Comes Home
# Runtime: 1h 46m
# Year: 2019
# {'movie_id': 'tt8350360', 'rank': '191', 'title': 'Annabelle Comes Home', 'runtime': '1h 46m', 'year': '2019', 'rating': '5.9', 'votes': '91K'}
# ===============================
#
# tt1053960
# 192
# The Midnight Sky
# Runtime: 1h 58m
# Year: 2020
# {'movie_id': 'tt1053960', 'rank': '192', 'title': 'The Midnight Sky', 'runtime': '1h 58m', 'year': '2020', 'rating': '5.7', 'votes': '91K'}
# ===============================
#
# tt3224458
# 193
# A Beautiful Day in the Neighborhood
# Runtime: 1h 49m
# Year: 2019
# {'movie_id': 'tt3224458', 'rank': '193', 'title': 'A Beautiful Day in the Neighborhood', 'runtime': '1h 49m', 'year': '2019', 'rating': '7.2', 'votes': '90K'}
# ===============================
#
# tt5688932
# 194
# Sorry to Bother You
# Runtime: 1h 52m
# Year: 2018
# {'movie_id': 'tt5688932', 'rank': '194', 'title': 'Sorry to Bother You', 'runtime': '1h 52m', 'year': '2018', 'rating': '6.9', 'votes': '90K'}
# ===============================
#
# tt6513120
# 195
# Fighting with My Family
# Runtime: 1h 48m
# Year: 2019
# {'movie_id': 'tt6513120', 'rank': '195', 'title': 'Fighting with My Family', 'runtime': '1h 48m', 'year': '2019', 'rating': '7.0', 'votes': '89K'}
# ===============================
#
# tt5220122
# 196
# Hotel Transylvania 3: Summer Vacation
# Runtime: 1h 37m
# Year: 2018
# {'movie_id': 'tt5220122', 'rank': '196', 'title': 'Hotel Transylvania 3: Summer Vacation', 'runtime': '1h 37m', 'year': '2018', 'rating': '6.3', 'votes': '89K'}
# ===============================
#
# tt8075192
# 197
# Shoplifters
# Runtime: 2h 1m
# Year: 2018
# {'movie_id': 'tt8075192', 'rank': '197', 'title': 'Shoplifters', 'runtime': '2h 1m', 'year': '2018', 'rating': '7.9', 'votes': '89K'}
# ===============================
#
# tt8155288
# 198
# Happy Death Day 2U
# Runtime: 1h 40m
# Year: 2019
# {'movie_id': 'tt8155288', 'rank': '198', 'title': 'Happy Death Day 2U', 'runtime': '1h 40m', 'year': '2019', 'rating': '6.2', 'votes': '89K'}
# ===============================
#
# tt8695030
# 199
# The Dead Don't Die
# Runtime: 1h 44m
# Year: 2019
# {'movie_id': 'tt8695030', 'rank': '199', 'title': "The Dead Don't Die", 'runtime': '1h 44m', 'year': '2019', 'rating': '5.5', 'votes': '89K'}
# ===============================
#
# tt4560436
# 200
# Mile 22
# Runtime: 1h 34m
# Year: 2018
# {'movie_id': 'tt4560436', 'rank': '200', 'title': 'Mile 22', 'runtime': '1h 34m', 'year': '2018', 'rating': '6.1', 'votes': '89K'}
# ===============================
#
# tt2531344
# 201
# Blockers
# Runtime: 1h 42m
# Year: 2018
# {'movie_id': 'tt2531344', 'rank': '201', 'title': 'Blockers', 'runtime': '1h 42m', 'year': '2018', 'rating': '6.2', 'votes': '88K'}
# ===============================
#
# tt3387520
# 202
# Scary Stories to Tell in the Dark
# Runtime: 1h 48m
# Year: 2019
# {'movie_id': 'tt3387520', 'rank': '202', 'title': 'Scary Stories to Tell in the Dark', 'runtime': '1h 48m', 'year': '2019', 'rating': '6.2', 'votes': '88K'}
# ===============================
#
# tt6472976
# 203
# Five Feet Apart
# Runtime: 1h 56m
# Year: 2019
# {'movie_id': 'tt6472976', 'rank': '203', 'title': 'Five Feet Apart', 'runtime': '1h 56m', 'year': '2019', 'rating': '7.2', 'votes': '87K'}
# ===============================
#
# tt1634106
# 204
# Bloodshot
# Runtime: 1h 49m
# Year: 2020
# {'movie_id': 'tt1634106', 'rank': '204', 'title': 'Bloodshot', 'runtime': '1h 49m', 'year': '2020', 'rating': '5.7', 'votes': '87K'}
# ===============================
#
# tt4575576
# 205
# Christopher Robin
# Runtime: 1h 44m
# Year: 2018
# {'movie_id': 'tt4575576', 'rank': '205', 'title': 'Christopher Robin', 'runtime': '1h 44m', 'year': '2018', 'rating': '7.2', 'votes': '86K'}
# ===============================
#
# tt6921996
# 206
# Johnny English Strikes Again
# Runtime: 1h 29m
# Year: 2018
# {'movie_id': 'tt6921996', 'rank': '206', 'title': 'Johnny English Strikes Again', 'runtime': '1h 29m', 'year': '2018', 'rating': '6.2', 'votes': '85K'}
# ===============================
#
# tt2990140
# 207
# The Christmas Chronicles
# Runtime: 1h 44m
# Year: 2018
# {'movie_id': 'tt2990140', 'rank': '207', 'title': 'The Christmas Chronicles', 'runtime': '1h 44m', 'year': '2018', 'rating': '7.0', 'votes': '85K'}
# ===============================
#
# tt3861390
# 208
# Dumbo
# Runtime: 1h 52m
# Year: 2019
# {'movie_id': 'tt3861390', 'rank': '208', 'title': 'Dumbo', 'runtime': '1h 52m', 'year': '2019', 'rating': '6.3', 'votes': '84K'}
# ===============================
#
# tt6663582
# 209
# The Spy Who Dumped Me
# Runtime: 1h 57m
# Year: 2018
# {'movie_id': 'tt6663582', 'rank': '209', 'title': 'The Spy Who Dumped Me', 'runtime': '1h 57m', 'year': '2018', 'rating': '6.0', 'votes': '84K'}
# ===============================
#
# tt6977338
# 210
# Good Boys
# Runtime: 1h 30m
# Year: 2019
# {'movie_id': 'tt6977338', 'rank': '210', 'title': 'Good Boys', 'runtime': '1h 30m', 'year': '2019', 'rating': '6.7', 'votes': '84K'}
# ...
#   'runtime': '1h 45m',
#   'year': '2018',
#   'rating': '5.6',
#   'votes': '40K'},
#  {'movie_id': 'tt3385524',
#   'rank': '396',
#   'title': 'Stan & Ollie',
#   'runtime': '1h 38m',
#   'year': '2018',
#   'rating': '7.2',
#   'votes': '40K'},
#  {'movie_id': 'tt1000300',
#   'rank': '397',
#   'title': 'The Rental',
#   'runtime': '1h 28m',
#   'year': '2020',
#   'rating': '5.7',
#   'votes': '40K'},
#  {'movie_id': 'tt5198068',
#   'rank': '398',
#   'title': 'Wolfwalkers',
#   'runtime': '1h 43m',
#   'year': '2020',
#   'rating': '8.0',
#   'votes': '40K'},
#  {'movie_id': 'tt1036246',
#   'rank': '399',
#   'title': 'After We Collided',
#   'runtime': '1h 45m',
#   'year': '2020',
#   'rating': '5.1',
#   'votes': '40K'},
#  {'movie_id': 'tt1478839',
#   'rank': '400',
#   'title': 'The Art of Racing in the Rain',
#   'runtime': '1h 49m',
#   'year': '2019',
#   'rating': '7.6',
#   'votes': '40K'},
#  {'movie_id': 'tt1255919',
#   'rank': '401',
#   'title': 'Holmes & Watson',
#   'runtime': '1h 30m',
#   'year': '2018',
#   'rating': '3.9',
#   'votes': '40K'},
#  {'movie_id': 'tt3907584',
#   'rank': '402',
#   'title': 'All the Bright Places',
#   'runtime': '1h 47m',
#   'year': '2020',
#   'rating': '6.6',
#   'votes': '40K'},
#  {'movie_id': 'tt4669788',
#   'rank': '403',
#   'title': 'On the Basis of Sex',
#   'runtime': '2h',
#   'year': '2018',
#   'rating': '7.1',
#   'votes': '40K'},
#  {'movie_id': 'tt4761916',
#   'rank': '404',
#   'title': 'Unfriended: Dark Web',
#   'runtime': '1h 32m',
#   'year': '2018',
#   'rating': '6.0',
#   'votes': '40K'},
#  {'movie_id': 'tt6697582',
#   'rank': '405',
#   'title': 'Arif V 216',
#   'runtime': '2h 5m',
#   'year': '2018',
#   'rating': '7.0',
#   'votes': '40K'},
#  {'movie_id': 'tt2639336',
#   'rank': '406',
#   'title': 'Greta',
#   'runtime': '1h 38m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '40K'},
#  {'movie_id': 'tt5690360',
#   'rank': '407',
#   'title': 'Slender Man',
#   'runtime': '1h 33m',
#   'year': '2018',
#   'rating': '3.3',
#   'votes': '40K'},
#  {'movie_id': 'tt9784456',
#   'rank': '408',
#   'title': 'The Kissing Booth 2',
#   'runtime': '2h 14m',
#   'year': '2020',
#   'rating': '5.7',
#   'votes': '40K'},
#  {'movie_id': 'tt8633462',
#   'rank': '409',
#   'title': 'Quo Vadis, Aida?',
#   'runtime': '1h 41m',
#   'year': '2020',
#   'rating': '8.0',
#   'votes': '40K'},
#  {'movie_id': 'tt7019842',
#   'rank': '410',
#   'title': '96',
#   'runtime': '2h 38m',
#   'year': '2018',
#   'rating': '8.5',
#   'votes': '39K'},
#  {'movie_id': 'tt8850222',
#   'rank': '411',
#   'title': 'Peninsula',
#   'runtime': '1h 56m',
#   'year': '2020',
#   'rating': '5.5',
#   'votes': '39K'},
#  {'movie_id': 'tt7905466',
#   'rank': '412',
#   'title': 'They Shall Not Grow Old',
#   'runtime': '1h 39m',
#   'year': '2018',
#   'rating': '8.2',
#   'votes': '39K'},
#  {'movie_id': 'tt4964788',
#   'rank': '413',
#   'title': 'Everybody Knows',
#   'runtime': '2h 13m',
#   'year': '2018',
#   'rating': '6.9',
#   'votes': '39K'},
#  {'movie_id': 'tt7725596',
#   'rank': '414',
#   'title': 'Badhaai Ho',
#   'runtime': '2h 4m',
#   'year': '2018',
#   'rating': '7.9',
#   'votes': '39K'},
#  {'movie_id': 'tt1464763',
#   'rank': '415',
#   'title': 'Mute',
#   'runtime': '2h 6m',
#   'year': '2018',
#   'rating': '5.5',
#   'votes': '39K'},
#  {'movie_id': 'tt6865690',
#   'rank': '416',
#   'title': 'The Professor',
#   'runtime': '1h 30m',
#   'year': '2018',
#   'rating': '6.7',
#   'votes': '39K'},
#  {'movie_id': 'tt7280898',
#   'rank': '417',
#   'title': '22 July',
#   'runtime': '2h 23m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '38K'},
#  {'movie_id': 'tt8242084',
#   'rank': '418',
#   'title': 'My Spy',
#   'runtime': '1h 39m',
#   'year': '2020',
#   'rating': '6.4',
#   'votes': '38K'},
#  {'movie_id': 'tt6141246',
#   'rank': '419',
#   'title': 'The Aeronauts',
#   'runtime': '1h 40m',
#   'year': '2019',
#   'rating': '6.6',
#   'votes': '38K'},
#  {'movie_id': 'tt7485048',
#   'rank': '420',
#   'title': 'Super 30',
#   'runtime': '2h 34m',
#   'year': '2019',
#   'rating': '7.9',
#   'votes': '38K'},
#  {'movie_id': 'tt4878482',
#   'rank': '421',
#   'title': "Dumplin'",
#   'runtime': '1h 50m',
#   'year': '2018',
#   'rating': '6.5',
#   'votes': '38K'},
#  {'movie_id': 'tt1052109',
#   'rank': '422',
#   'title': 'The Forgotten Battle',
#   'runtime': '2h 4m',
#   'year': '2020',
#   'rating': '7.1',
#   'votes': '38K'},
#  {'movie_id': 'tt5523010',
#   'rank': '423',
#   'title': 'The Nutcracker and the Four Realms',
#   'runtime': '1h 39m',
#   'year': '2018',
#   'rating': '5.6',
#   'votes': '38K'},
#  {'movie_id': 'tt5935704',
#   'rank': '424',
#   'title': 'Padmaavat',
#   'runtime': '2h 43m',
#   'year': '2018',
#   'rating': '7.1',
#   'votes': '38K'},
#  {'movie_id': 'tt2076298',
#   'rank': '425',
#   'title': 'Ip Man 4: The Finale',
#   'runtime': '1h 47m',
#   'year': '2019',
#   'rating': '7.0',
#   'votes': '38K'},
#  {'movie_id': 'tt7608028',
#   'rank': '426',
#   'title': 'The Open House',
#   'runtime': '1h 34m',
#   'year': '2018',
#   'rating': '3.3',
#   'votes': '38K'},
#  {'movie_id': 'tt1032414',
#   'rank': '427',
#   'title': 'Article 15',
#   'runtime': '2h 10m',
#   'year': '2019',
#   'rating': '8.1',
#   'votes': '38K'},
#  {'movie_id': 'tt6285944',
#   'rank': '428',
#   'title': 'The Banker',
#   'runtime': '2h',
#   'year': '2020',
#   'rating': '7.3',
#   'votes': '38K'},
#  {'movie_id': 'tt4073790',
#   'rank': '429',
#   'title': 'The Darkest Minds',
#   'runtime': '1h 44m',
#   'year': '2018',
#   'rating': '5.7',
#   'votes': '38K'},
#  {'movie_id': 'tt1072748',
#   'rank': '430',
#   'title': 'Winchester',
#   'runtime': '1h 39m',
#   'year': '2018',
#   'rating': '5.5',
#   'votes': '38K'},
#  {'movie_id': 'tt9606374',
#   'rank': '431',
#   'title': 'On the Rocks',
#   'runtime': '1h 36m',
#   'year': '2020',
#   'rating': '6.4',
#   'votes': '37K'},
#  {'movie_id': 'tt4799066',
#   'rank': '432',
#   'title': 'Midnight Sun',
#   'runtime': '1h 31m',
#   'year': '2018',
#   'rating': '6.6',
#   'votes': '37K'},
#  {'movie_id': 'tt9398640',
#   'rank': '433',
#   'title': 'Between Two Ferns: The Movie',
#   'runtime': '1h 22m',
#   'year': '2019',
#   'rating': '6.1',
#   'votes': '37K'},
#  {'movie_id': 'tt4068576',
#   'rank': '434',
#   'title': 'The Nightingale',
#   'runtime': '2h 16m',
#   'year': '2018',
#   'rating': '7.3',
#   'votes': '37K'},
#  {'movie_id': 'tt9806192',
#   'rank': '435',
#   'title': 'I Lost My Body',
#   'runtime': '1h 21m',
#   'year': '2019',
#   'rating': '7.5',
#   'votes': '37K'},
#  {'movie_id': 'tt7605074',
#   'rank': '436',
#   'title': 'The Wandering Earth',
#   'runtime': '2h 5m',
#   'year': '2019',
#   'rating': '5.9',
#   'votes': '37K'},
#  {'movie_id': 'tt1285009',
#   'rank': '437',
#   'title': 'The Strangers: Prey at Night',
#   'runtime': '1h 25m',
#   'year': '2018',
#   'rating': '5.3',
#   'votes': '37K'},
#  {'movie_id': 'tt8361028',
#   'rank': '438',
#   'title': 'Cam',
#   'runtime': '1h 34m',
#   'year': '2018',
#   'rating': '5.9',
#   'votes': '37K'},
#  {'movie_id': 'tt6095472',
#   'rank': '439',
#   'title': 'The Angry Birds Movie 2',
#   'runtime': '1h 37m',
#   'year': '2019',
#   'rating': '6.4',
#   'votes': '37K'},
#  {'movie_id': 'tt3256226',
#   'rank': '440',
#   'title': 'IO',
#   'runtime': '1h 36m',
#   'year': '2019',
#   'rating': '4.8',
#   'votes': '37K'},
#  {'movie_id': 'tt6269368',
#   'rank': '441',
#   'title': 'The Clovehitch Killer',
#   'runtime': '1h 49m',
#   'year': '2018',
#   'rating': '6.5',
#   'votes': '37K'},
#  {'movie_id': 'tt8108274',
#   'rank': '442',
#   'title': 'Tanhaji: The Unsung Warrior',
#   'runtime': '2h 15m',
#   'year': '2020',
#   'rating': '7.5',
#   'votes': '37K'},
#  {'movie_id': 'tt1105764',
#   'rank': '443',
#   'title': 'The Christmas Chronicles: Part Two',
#   'runtime': '1h 52m',
#   'year': '2020',
#   'rating': '6.0',
#   'votes': '36K'},
#  {'movie_id': 'tt9340860',
#   'rank': '444',
#   'title': 'Let Him Go',
#   'runtime': '1h 53m',
#   'year': '2020',
#   'rating': '6.7',
#   'votes': '36K'},
#  {'movie_id': 'tt8108268',
#   'rank': '445',
#   'title': 'The Tashkent Files',
#   'runtime': '2h 14m',
#   'year': '2019',
#   'rating': '8.1',
#   'votes': '36K'},
#  {'movie_id': 'tt6513656',
#   'rank': '446',
#   'title': 'Escape Plan 2: Hades',
#   'runtime': '1h 33m',
#   'year': '2018',
#   'rating': '3.9',
#   'votes': '36K'},
#  {'movie_id': 'tt7547410',
#   'rank': '447',
#   'title': 'Dora and the Lost City of Gold',
#   'runtime': '1h 42m',
#   'year': '2019',
#   'rating': '6.1',
#   'votes': '36K'},
#  {'movie_id': 'tt6802308',
#   'rank': '448',
#   'title': 'The 15:17 to Paris',
#   'runtime': '1h 34m',
#   'year': '2018',
#   'rating': '5.3',
#   'votes': '36K'},
#  {'movie_id': 'tt9086228',
#   'rank': '449',
#   'title': 'Gretel & Hansel',
#   'runtime': '1h 27m',
#   'year': '2020',
#   'rating': '5.5',
#   'votes': '36K'},
#  {'movie_id': 'tt7149730',
#   'rank': '450',
#   'title': 'The Silencing',
#   'runtime': '1h 33m',
#   'year': '2020',
#   'rating': '6.3',
#   'votes': '36K'},
#  {'movie_id': 'tt7946422',
#   'rank': '451',
#   'title': 'Prospect',
#   'runtime': '1h 40m',
#   'year': '2018',
#   'rating': '6.3',
#   'votes': '36K'},
#  {'movie_id': 'tt1035062',
#   'rank': '452',
#   'title': 'Gunjan Saxena: The Kargil Girl',
#   'runtime': '1h 52m',
#   'year': '2020',
#   'rating': '5.5',
#   'votes': '36K'},
#  {'movie_id': 'tt1131714',
#   'rank': '453',
#   'title': 'Shiva Baby',
#   'runtime': '1h 17m',
#   'year': '2020',
#   'rating': '7.1',
#   'votes': '36K'},
#  {'movie_id': 'tt4357394',
#   'rank': '454',
#   'title': 'Tau',
#   'runtime': '1h 37m',
#   'year': '2018',
#   'rating': '5.8',
#   'votes': '36K'},
#  {'movie_id': 'tt5144174',
#   'rank': '455',
#   'title': 'The Dry',
#   'runtime': '1h 57m',
#   'year': '2020',
#   'rating': '6.8',
#   'votes': '36K'},
#  {'movie_id': 'tt5501104',
#   'rank': '456',
#   'title': 'Border',
#   'runtime': '1h 50m',
#   'year': '2018',
#   'rating': '7.0',
#   'votes': '35K'},
#  {'movie_id': 'tt8722346',
#   'rank': '457',
#   'title': 'Queen & Slim',
#   'runtime': '2h 12m',
#   'year': '2019',
#   'rating': '7.1',
#   'votes': '35K'},
#  {'movie_id': 'tt1061292',
#   'rank': '458',
#   'title': 'One Night in Miami...',
#   'runtime': '1h 54m',
#   'year': '2020',
#   'rating': '7.1',
#   'votes': '35K'},
#  {'movie_id': 'tt9477520',
#   'rank': '459',
#   'title': 'Asuran',
#   'runtime': '2h 21m',
#   'year': '2019',
#   'rating': '8.4',
#   'votes': '35K'},
#  {'movie_id': 'tt6218358',
#   'rank': '460',
#   'title': 'Calibre',
#   'runtime': '1h 41m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '35K'},
#  {'movie_id': 'tt7430722',
#   'rank': '461',
#   'title': 'War',
#   'runtime': '2h 31m',
#   'year': '2019',
#   'rating': '6.5',
#   'votes': '34K'},
#  {'movie_id': 'tt6436726',
#   'rank': '462',
#   'title': '7500',
#   'runtime': '1h 33m',
#   'year': '2019',
#   'rating': '6.3',
#   'votes': '34K'},
#  {'movie_id': 'tt7098658',
#   'rank': '463',
#   'title': 'Raazi',
#   'runtime': '2h 18m',
#   'year': '2018',
#   'rating': '7.7',
#   'votes': '34K'},
#  {'movie_id': 'tt6987770',
#   'rank': '464',
#   'title': 'Destination Wedding',
#   'runtime': '1h 27m',
#   'year': '2018',
#   'rating': '6.0',
#   'votes': '34K'},
#  {'movie_id': 'tt1298789',
#   'rank': '465',
#   'title': 'American Murder: The Family Next Door',
#   'runtime': '1h 23m',
#   'year': '2020',
#   'rating': '7.2',
#   'votes': '34K'},
#  {'movie_id': 'tt4986098',
#   'rank': '466',
#   'title': 'The Titan',
#   'runtime': '1h 37m',
#   'year': '2018',
#   'rating': '4.8',
#   'votes': '34K'},
#  {'movie_id': 'tt3317234',
#   'rank': '467',
#   'title': 'Game Over, Man!',
#   'runtime': '1h 41m',
#   'year': '2018',
#   'rating': '5.5',
#   'votes': '34K'},
#  {'movie_id': 'tt7242142',
#   'rank': '468',
#   'title': 'Blindspotting',
#   'runtime': '1h 35m',
#   'year': '2018',
#   'rating': '7.4',
#   'votes': '33K'},
#  {'movie_id': 'tt4995776',
#   'rank': '469',
#   'title': 'The Red Sea Diving Resort',
#   'runtime': '2h 9m',
#   'year': '2019',
#   'rating': '6.6',
#   'votes': '33K'},
#  {'movie_id': 'tt6857166',
#   'rank': '470',
#   'title': 'Book Club',
#   'runtime': '1h 44m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '33K'},
#  {'movie_id': 'tt7961060',
#   'rank': '471',
#   'title': 'Dragon Ball Super: Broly',
#   'runtime': '1h 40m',
#   'year': '2018',
#   'rating': '7.7',
#   'votes': '33K'},
#  {'movie_id': 'tt9196192',
#   'rank': '472',
#   'title': 'Cuties',
#   'runtime': '1h 36m',
#   'year': '2020',
#   'rating': '3.6',
#   'votes': '33K'},
#  {'movie_id': 'tt8652728',
#   'rank': '473',
#   'title': 'Waves',
#   'runtime': '2h 15m',
#   'year': '2019',
#   'rating': '7.5',
#   'votes': '33K'},
#  {'movie_id': 'tt7721800',
#   'rank': '474',
#   'title': 'Bharat',
#   'runtime': '2h 30m',
#   'year': '2019',
#   'rating': '4.7',
#   'votes': '33K'},
#  {'movie_id': 'tt3721964',
#   'rank': '475',
#   'title': 'Gringo',
#   'runtime': '1h 51m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '33K'},
#  {'movie_id': 'tt7634968',
#   'rank': '476',
#   'title': 'What Men Want',
#   'runtime': '1h 57m',
#   'year': '2019',
#   'rating': '5.4',
#   'votes': '33K'},
#  {'movie_id': 'tt7748244',
#   'rank': '477',
#   'title': 'Mortal World',
#   'runtime': '1h 47m',
#   'year': '2018',
#   'rating': '7.6',
#   'votes': '33K'},
#  {'movie_id': 'tt7137380',
#   'rank': '478',
#   'title': 'Destroyer',
#   'runtime': '2h 1m',
#   'year': '2018',
#   'rating': '6.2',
#   'votes': '32K'},
#  {'movie_id': 'tt9691136',
#   'rank': '479',
#   'title': 'Shadow in the Cloud',
#   'runtime': '1h 23m',
#   'year': '2020',
#   'rating': '5.0',
#   'votes': '32K'},
#  {'movie_id': 'tt9354944',
#   'rank': '480',
#   'title': 'Jexi',
#   'runtime': '1h 24m',
#   'year': '2019',
#   'rating': '6.1',
#   'votes': '32K'},
#  {'movie_id': 'tt8954732',
#   'rank': '481',
#   'title': 'The Princess Switch',
#   'runtime': '1h 41m',
#   'year': '2018',
#   'rating': '6.1',
#   'votes': '32K'},
#  {'movie_id': 'tt5929754',
#   'rank': '482',
#   'title': 'Wildlife',
#   'runtime': '1h 45m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '32K'},
#  {'movie_id': 'tt7329656',
#   'rank': '483',
#   'title': '47 Meters Down: Uncaged',
#   'runtime': '1h 30m',
#   'year': '2019',
#   'rating': '5.0',
#   'votes': '32K'},
#  {'movie_id': 'tt8130968',
#   'rank': '484',
#   'title': 'Badla',
#   'runtime': '1h 58m',
#   'year': '2019',
#   'rating': '7.7',
#   'votes': '32K'},
#  {'movie_id': 'tt7772582',
#   'rank': '485',
#   'title': 'Never Rarely Sometimes Always',
#   'runtime': '1h 41m',
#   'year': '2020',
#   'rating': '7.4',
#   'votes': '32K'},
#  {'movie_id': 'tt4648786',
#   'rank': '486',
#   'title': 'Harriet',
#   'runtime': '2h 5m',
#   'year': '2019',
#   'rating': '6.7',
#   'votes': '32K'},
#  {'movie_id': 'tt6288124',
#   'rank': '487',
#   'title': "Don't Worry, He Won't Get Far on Foot",
#   'runtime': '1h 54m',
#   'year': '2018',
#   'rating': '6.8',
#   'votes': '32K'},
#  {'movie_id': 'tt2762506',
#   'rank': '488',
#   'title': 'Bacurau',
#   'runtime': '2h 11m',
#   'year': '2019',
#   'rating': '7.3',
#   'votes': '31K'},
#  {'movie_id': 'tt7711170',
#   'rank': '489',
#   'title': 'Alone',
#   'runtime': '1h 38m',
#   'year': '2020',
#   'rating': '6.2',
#   'votes': '31K'},
#  {'movie_id': 'tt9573980',
#   'rank': '490',
#   'title': 'Leaving Neverland',
#   'runtime': '4h',
#   'year': '2019',
#   'rating': '7.0',
#   'votes': '31K'},
#  {'movie_id': 'tt9072352',
#   'rank': '491',
#   'title': 'Relic',
#   'runtime': '1h 29m',
#   'year': '2020',
#   'rating': '6.0',
#   'votes': '31K'},
#  {'movie_id': 'tt9252468',
#   'rank': '492',
#   'title': 'Mosul',
#   'runtime': '1h 41m',
#   'year': '2019',
#   'rating': '7.1',
#   'votes': '31K'},
#  {'movie_id': 'tt2126357',
#   'rank': '493',
#   'title': 'Second Act',
#   'runtime': '1h 43m',
#   'year': '2018',
#   'rating': '5.8',
#   'votes': '31K'},
#  {'movie_id': 'tt3152592',
#   'rank': '494',
#   'title': 'Scoob!',
#   'runtime': '1h 33m',
#   'year': '2020',
#   'rating': '5.6',
#   'votes': '31K'},
#  {'movie_id': 'tt6527426',
#   'rank': '495',
#   'title': 'Zero',
#   'runtime': '2h 44m',
#   'year': '2018',
#   'rating': '5.2',
#   'votes': '31K'},
#  {'movie_id': 'tt3089630',
#   'rank': '496',
#   'title': 'Artemis Fowl',
#   'runtime': '1h 35m',
#   'year': '2020',
#   'rating': '4.3',
#   'votes': '31K'},
#  {'movie_id': 'tt1308728',
#   'rank': '497',
#   'title': 'The Happytime Murders',
#   'runtime': '1h 31m',
#   'year': '2018',
#   'rating': '5.5',
#   'votes': '31K'},
#  {'movie_id': 'tt1138238',
#   'rank': '498',
#   'title': 'The Dissident',
#   'runtime': '1h 59m',
#   'year': '2020',
#   'rating': '7.8',
#   'votes': '31K'},
#  {'movie_id': 'tt1031014',
#   'rank': '499',
#   'title': 'Fatman',
#   'runtime': '1h 40m',
#   'year': '2020',
#   'rating': '5.9',
#   'votes': '31K'},
#  {'movie_id': 'tt1006569',
#   'rank': '500',
#   'title': 'Antebellum',
#   'runtime': '1h 45m',
#   'year': '2020',
#   'rating': '5.8',
#   'votes': '31K'}]

# %%
print(Movies_list)
# Out:
# [{'movie_id': 'tt7286456', 'rank': '1', 'title': 'Joker', 'runtime': '2h 2m', 'year': '2019', 'rating': '8.4', 'votes': '1.6M'}, {'movie_id': 'tt4154796', 'rank': '2', 'title': 'Avengers: Endgame', 'runtime': '3h 1m', 'year': '2019', 'rating': '8.4', 'votes': '1.3M'}, {'movie_id': 'tt4154756', 'rank': '3', 'title': 'Avengers: Infinity War', 'runtime': '2h 29m', 'year': '2018', 'rating': '8.4', 'votes': '1.2M'}, {'movie_id': 'tt6751668', 'rank': '4', 'title': 'Parasite', 'runtime': '2h 12m', 'year': '2019', 'rating': '8.5', 'votes': '1M'}, {'movie_id': 'tt7131622', 'rank': '5', 'title': 'Once Upon a Time..', 'runtime': '2h 41m', 'year': '2019', 'rating': '7.6', 'votes': '878K'}, {'movie_id': 'tt1825683', 'rank': '6', 'title': 'Black Panther', 'runtime': '2h 14m', 'year': '2018', 'rating': '7.3', 'votes': '856K'}, {'movie_id': 'tt8946378', 'rank': '7', 'title': 'Knives Out', 'runtime': '2h 10m', 'year': '2019', 'rating': '7.9', 'votes': '796K'}, {'movie_id': 'tt8579674', 'rank': '8', 'title': '1917', 'runtime': '1h 59m', 'year': '2019', 'rating': '8.2', 'votes': '703K'}, {'movie_id': 'tt4633694', 'rank': '9', 'title': 'Spider-Man: Into the Spider-Verse', 'runtime': '1h 57m', 'year': '2018', 'rating': '8.4', 'votes': '702K'}, {'movie_id': 'tt5463162', 'rank': '10', 'title': 'Deadpool 2', 'runtime': '1h 59m', 'year': '2018', 'rating': '7.6', 'votes': '691K'}, {'movie_id': 'tt4154664', 'rank': '11', 'title': 'Captain Marvel', 'runtime': '2h 3m', 'year': '2019', 'rating': '6.8', 'votes': '624K'}, {'movie_id': 'tt6644200', 'rank': '12', 'title': 'A Quiet Place', 'runtime': '1h 30m', 'year': '2018', 'rating': '7.5', 'votes': '613K'}, {'movie_id': 'tt6723592', 'rank': '13', 'title': 'Tenet', 'runtime': '2h 30m', 'year': '2020', 'rating': '7.3', 'votes': '612K'}, {'movie_id': 'tt1727824', 'rank': '14', 'title': 'Bohemian Rhapsody', 'runtime': '2h 14m', 'year': '2018', 'rating': '7.9', 'votes': '609K'}, {'movie_id': 'tt6966692', 'rank': '15', 'title': 'Green Book', 'runtime': '2h 10m', 'year': '2018', 'rating': '8.2', 'votes': '605K'}, {'movie_id': 'tt6320628', 'rank': '16', 'title': 'Spider-Man: Far from Home', 'runtime': '2h 9m', 'year': '2019', 'rating': '7.4', 'votes': '577K'}, {'movie_id': 'tt1270797', 'rank': '17', 'title': 'Venom', 'runtime': '1h 52m', 'year': '2018', 'rating': '6.6', 'votes': '560K'}, {'movie_id': 'tt1477834', 'rank': '18', 'title': 'Aquaman', 'runtime': '2h 23m', 'year': '2018', 'rating': '6.8', 'votes': '530K'}, {'movie_id': 'tt2527338', 'rank': '19', 'title': 'Star Wars: Episode IX - The Rise of Skywalker', 'runtime': '2h 21m', 'year': '2019', 'rating': '6.4', 'votes': '506K'}, {'movie_id': 'tt1677720', 'rank': '20', 'title': 'Ready Player One', 'runtime': '2h 20m', 'year': '2018', 'rating': '7.4', 'votes': '502K'}, {'movie_id': 'tt1950186', 'rank': '21', 'title': 'Ford v Ferrari', 'runtime': '2h 32m', 'year': '2019', 'rating': '8.1', 'votes': '501K'}, {'movie_id': 'tt5095030', 'rank': '22', 'title': 'Ant-Man and the Wasp', 'runtime': '1h 58m', 'year': '2018', 'rating': '7.0', 'votes': '462K'}, {'movie_id': 'tt2584384', 'rank': '23', 'title': 'Jojo Rabbit', 'runtime': '1h 48m', 'year': '2019', 'rating': '7.9', 'votes': '455K'}, {'movie_id': 'tt1302006', 'rank': '24', 'title': 'The Irishman', 'runtime': '3h 29m', 'year': '2019', 'rating': '7.8', 'votes': '442K'}, {'movie_id': 'tt6146586', 'rank': '25', 'title': 'John Wick: Chapter 3 - Parabellum', 'runtime': '2h 10m', 'year': '2019', 'rating': '7.4', 'votes': '440K'}, {'movie_id': 'tt8772262', 'rank': '26', 'title': 'Midsommar', 'runtime': '2h 28m', 'year': '2019', 'rating': '7.1', 'votes': '429K'}, {'movie_id': 'tt1517451', 'rank': '27', 'title': 'A Star Is Born', 'runtime': '2h 16m', 'year': '2018', 'rating': '7.6', 'votes': '429K'}, {'movie_id': 'tt8367814', 'rank': '28', 'title': 'The Gentlemen', 'runtime': '1h 53m', 'year': '2019', 'rating': '7.8', 'votes': '419K'}, {'movie_id': 'tt7784604', 'rank': '29', 'title': 'Hereditary', 'runtime': '2h 7m', 'year':  ...

# %%
# to convert the movies list of dics to dataframe
df_movies = pd.DataFrame(Movies_list)
df_movies
# Out:
#       movie_id rank                   title runtime  year rating votes
# 0    tt7286456    1                   Joker   2h 2m  2019    8.4  1.6M
# 1    tt4154796    2       Avengers: Endgame   3h 1m  2019    8.4  1.3M
# 2    tt4154756    3  Avengers: Infinity War  2h 29m  2018    8.4  1.2M
# 3    tt6751668    4                Parasite  2h 12m  2019    8.5    1M
# 4    tt7131622    5      Once Upon a Time..  2h 41m  2019    7.6  878K
# ..         ...  ...                     ...     ...   ...    ...   ...
# 495  tt3089630  496            Artemis Fowl  1h 35m  2020    4.3   31K
# 496  tt1308728  497   The Happytime Murders  1h 31m  2018    5.5   31K
# 497  tt1138238  498           The Dissident  1h 59m  2020    7.8   31K
# 498  tt1031014  499                  Fatman  1h 40m  2020    5.9   31K
# 499  tt1006569  500              Antebellum  1h 45m  2020    5.8   31K
#
# [500 rows x 7 columns]

# %% [markdown]
# ***
# #  To export the colleted movies to IMDb_TopVoted.csv file.

# %%
df_movies.to_csv('IMDb_TopVoted_Group6.csv', index = False)

# %% [markdown]
# # Importing the given dataset "Movies.csv" to Pandas DataFrame called df1

# %%
# Importing the csv file to df1 and print the df1.

df1 = pd.read_csv ('Movies.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        500 non-null    object
#  1   originalTitle   500 non-null    object
#  2   description     500 non-null    object
#  3   ratingCategory  497 non-null    object
#  4   genres          500 non-null    object
# dtypes: object(5)
# memory usage: 19.7+ KB

# %% [markdown]
# # Import the scraped data from the IMDb_TopVoted.csv file to Pandas DataFrame called df2

# %%
# You need to import the collected dataset "IMDb_TopVoted.csv" and print the df2.
# To handel Latin characters that may contained in the csv file
# with no issue, use  encoding= "ISO-8859-1" with the pd.read_csv()
# Example: df1 = pd.read_csv('thefilename.csv', encoding= "ISO-8859-1") 
# Using encoding= "ISO-8859-1" will avoid Unicode-Decode-Errors.

df2 = pd.read_csv('IMDb_TopVoted_Group6.csv)', encoding= "ISO-8859-1")
df2
# Out:
#       movie_id  rank                   title runtime  year  rating votes
# 0    tt7286456     1                   Joker   2h 2m  2019     8.4  1.6M
# 1    tt4154796     2       Avengers: Endgame   3h 1m  2019     8.4  1.3M
# 2    tt4154756     3  Avengers: Infinity War  2h 29m  2018     8.4  1.2M
# 3    tt6751668     4                Parasite  2h 12m  2019     8.5    1M
# 4    tt7131622     5      Once Upon a Time..  2h 41m  2019     7.6  878K
# ..         ...   ...                     ...     ...   ...     ...   ...
# 495  tt3089630   496            Artemis Fowl  1h 35m  2020     4.3   31K
# 496  tt1308728   497   The Happytime Murders  1h 31m  2018     5.5   31K
# 497  tt1138238   498           The Dissident  1h 59m  2020     7.8   31K
# 498  tt1031014   499                  Fatman  1h 40m  2020     5.9   31K
# 499  tt1006569   500              Antebellum  1h 45m  2020     5.8   31K
#
# [500 rows x 7 columns]

# %% [markdown]
# # Data cleansing and transformation for df2.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  500 non-null    object
#  1   rank      500 non-null    int64
#  2   title     500 non-null    object
#  3   runtime   500 non-null    object
#  4   year      500 non-null    int64
#  5   rating    500 non-null    float64
#  6   votes     500 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 27.5+ KB

# %%
df2.info()
df2.shape
df2_Rows = df2.shape[0]
df2_Columns = df2.shape[1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   movie_id  500 non-null    object
#  1   rank      500 non-null    int64
#  2   title     500 non-null    object
#  3   runtime   500 non-null    object
#  4   year      500 non-null    int64
#  5   rating    500 non-null    float64
#  6   votes     500 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 27.5+ KB

# %%
print(f"df2 dataset contains {df2_Rows} rows and {df2_Columns} columns.")
# Out:
# df2 dataset contains 500 rows and 7 columns.

# %%
df2.isnull().sum()
# Out:
# movie_id    0
# rank        0
# title       0
# runtime     0
# year        0
# rating      0
# votes       0
# dtype: int64

# %%
df2.duplicated
duplicate = df2[df2.duplicated()]
  
print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
# Empty DataFrame
# Columns: [movie_id, rank, title, runtime, year, rating, votes]
# Index: []

# %% [markdown]
# ---
#
# ## Data Profiling Summary
# ### List of the issues that the data contains

# %% [markdown]
# Steps for Data Profiling and Transformation
#
# 1. Convert Data Types:
# Ensure the rank and year columns are converted to integers for consistency and accurate numerical operations.
#
# 2. Normalize the votes Column:
# Create a function to convert votes values into integers:
# If the value contains M, multiply the numeric portion by 1,000,000.
# If the value contains K, multiply the numeric portion by 1,000.
# Ensure all votes values are stored as integers.
#
# 3. Standardize the runtime Column:
# Rename the runtime column to runtimeMinutes for clarity.
# Convert runtime values into minutes using a custom function:
# Extract hours (h) and minutes (m), calculate the total runtime in minutes.
# Replace the original runtime format (e.g., 2h 2m) with the computed integer values.
#
# 4. Redundant Columns:
# Drop the original runtime column after creating runtimeMinutes to avoid duplication.

# %% [markdown]
# ---
# ---
# ---
#
#
#
#
#
#
# # Data  Cleansing

# %%
# Cleaning and tranforming df2
 # rank, year, and votes should have a numeric integer data type.
 # runtime column should be renamed to runtimeMinutes and the value should be in minutes, 
 # for example: 2h 2m should be 122
    
# 1. Convert 'rank' and 'year' to integers
df2['rank'] = df2['rank'].astype(int)
df2['year'] = df2['year'].astype(int)

# 2. Method that performs the action of converting 'votes' to integers and removing 'M' or 'K'
# This method will be called in the below lines of code
def convert_votes(votes):
    # Ensure the input is a string for processing
    votes = str(votes) if not pd.isna(votes) else ''
    if 'M' in votes:
        return int(float(votes.replace('M', '')) * 1000000)
    elif 'K' in votes:
        return int(float(votes.replace('K', '')) * 1000)
    elif votes.isdigit():  # Check if the value is a plain numeric string
        return int(votes)
    else:
        return 0  # Default value for invalid or missing data

# Apply the function to the 'votes' column
df2['votes'] = df2['votes'].apply(convert_votes)


# 3. Rename 'runtime' to 'runtimeMinutes' and convert to minutes
def convert_runtime_to_runtimeMinutes(runtime):
    hours, minutes = 0, 0
    if 'h' in runtime:
        hours = int(runtime.split('h')[0].strip())
        runtime = runtime.split('h')[1].strip()  # Keep only the part after hours
    if 'm' in runtime:
        minutes = int(runtime.split('m')[0].strip())
    return hours * 60 + minutes

df2['runtimeMinutes'] = df2['runtime'].apply(convert_runtime_to_runtimeMinutes)
df2.drop(columns=['runtime'], inplace=True)  # Drop the original 'runtime' column

# Final DataFrame
print(df2.info())
print(df2.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        500 non-null    object
#  1   rank            500 non-null    int32
#  2   title           500 non-null    object
#  3   year            500 non-null    int32
#  4   rating          500 non-null    float64
#  5   votes           500 non-null    int64
#  6   runtimeMinutes  500 non-null    int64
# dtypes: float64(1), int32(2), int64(2), object(2)
# memory usage: 23.6+ KB
# None
#     movie_id  rank                   title  year  rating    votes  \
# 0  tt7286456     1                   Joker  2019     8.4  1600000
# 1  tt4154796     2       Avengers: Endgame  2019     8.4  1300000
# 2  tt4154756     3  Avengers: Infinity War  2018     8.4  1200000
# 3  tt6751668     4                Parasite  2019     8.5  1000000
# 4  tt7131622     5      Once Upon a Time..  2019     7.6   878000
#
#    runtimeMinutes
# 0             122
# 1             181
# 2             149
# 3             132
# 4             161

# %% [markdown]
# # 	Enrich the given dataset (df1) by merging it to the scraped data (df2).

# %%
# Merege the two dataframes to one dataframe called df.

# Merge the datasets on the 'movie_id' column
df = pd.merge(df1, df2, on='movie_id', how='left')

# Display the structure and first few rows of the enriched dataset
print(df.info())

df.dropna(inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        500 non-null    object
#  1   originalTitle   500 non-null    object
#  2   description     500 non-null    object
#  3   ratingCategory  497 non-null    object
#  4   genres          500 non-null    object
#  5   rank            498 non-null    float64
#  6   title           498 non-null    object
#  7   year            498 non-null    float64
#  8   rating          498 non-null    float64
#  9   votes           498 non-null    float64
#  10  runtimeMinutes  498 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 43.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Index: 495 entries, 0 to 498
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        495 non-null    object
#  1   originalTitle   495 non-null    object
#  2   description     495 non-null    object
#  3   ratingCategory  495 non-null    object
#  4   genres          495 non-null    object
#  5   rank            495 non-null    float64
#  6   title           495 non-null    object
#  7   year            495 non-null    float64
#  8   rating          495 non-null    float64
#  9   votes           495 non-null    float64
#  10  runtimeMinutes  495 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 46.4+ KB
# None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 495 entries, 0 to 498
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        495 non-null    object
#  1   originalTitle   495 non-null    object
#  2   description     495 non-null    object
#  3   ratingCategory  495 non-null    object
#  4   genres          495 non-null    object
#  5   rank            495 non-null    float64
#  6   title           495 non-null    object
#  7   year            495 non-null    float64
#  8   rating          495 non-null    float64
#  9   votes           495 non-null    float64
#  10  runtimeMinutes  495 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 46.4+ KB

# %%
df['rank'] = df['rank'].astype(int)
df['year'] = df['year'].astype(int)
df['votes'] = df['votes'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 495 entries, 0 to 498
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   movie_id        495 non-null    object
#  1   originalTitle   495 non-null    object
#  2   description     495 non-null    object
#  3   ratingCategory  495 non-null    object
#  4   genres          495 non-null    object
#  5   rank            495 non-null    int32
#  6   title           495 non-null    object
#  7   year            495 non-null    int32
#  8   rating          495 non-null    float64
#  9   votes           495 non-null    int32
#  10  runtimeMinutes  495 non-null    float64
# dtypes: float64(2), int32(3), object(6)
# memory usage: 40.6+ KB

# %% [markdown]
# #
# Rearrange the dataset fields to be listed in the following order:
# movie_id , rank , title ,  originalTitle ,  description ,
#           year ,  votes , rating ,  runtimeMinutes ,  ratingCategory ,  genres

# %%
df = df[["movie_id" , "rank" , "title" , "originalTitle" , "description" , "year" , "votes" , "rating" , "runtimeMinutes" , "ratingCategory" , "genres"]]
df.head()
# Out:
#     movie_id  rank                   title           originalTitle  \
# 0  tt7286456     1                   Joker                   Joker
# 1  tt4154796     2       Avengers: Endgame       Avengers: Endgame
# 2  tt4154756     3  Avengers: Infinity War  Avengers: Infinity War
# 3  tt6751668     4                Parasite                Parasite
# 4  tt1825683     6           Black Panther           Black Panther
#
#                                          description  year    votes  rating  \
# 0  During the 1980s, a failed stand-up comedian i...  2019  1600000     8.4
# 1  After the devastating events of Avengers: Infi...  2019  1300000     8.4
# 2  The Avengers and their allies must be willing ...  2018  1200000     8.4
# 3  Greed and class discrimination threaten the ne...  2019  1000000     8.5
# 4  T'Challa, heir to the hidden but advanced king...  2018   856000     7.3
#
#    runtimeMinutes ratingCategory                   genres
# 0           122.0              R     Crime,Drama,Thriller
# 1           181.0          PG-13   Action,Adventure,Drama
# 2           149.0          PG-13  Action,Adventure,Sci-Fi
# 3           132.0              R           Drama,Thriller
# 4           134.0          PG-13  Action,Adventure,Sci-Fi

# %% [markdown]
# # Export the enriched dataset to a CSV file:

# %%
# Use the following naming convention: 
#  Project_3_PartA_Lastname.csv
df.to_csv('Project_3_Part_A_Group6.csv', index = False)
